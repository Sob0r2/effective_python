# %% [markdown]
# # Lab 07

# %% [markdown]
# ## Zadanie 1

# %% [markdown]
# Przygotuj demo programu znajdującego miejsca zerowe metodą Newtona. Wykorzystując `argparse` ([link](https://docs.python.org/3.6/library/argparse.html#module-argparse)) lub `optparse` ([link](https://docs.python.org/3.6/library/optparse.html)) obsłuż:
# - ustalane punktu startowego,
# - wielkość kroku w pochodnej,
# - ilość kroków metody,
# - dokładność
# - pomoc
#
# Program uruchamiamy podając, np.:

# %%
from scipy.optimize import newton
import argparse

def function(l):
    return eval(l)

parser = argparse.ArgumentParser(prog="Newton",  description='Calculate x0 using Newton\'s method')
parser.add_argument("-f", dest="fun", type=function, help = "add function formula", required=True)
parser.add_argument("-x", dest="x0", type=float, help = "add starting point", required= True )
parser.add_argument('-s', dest="step", type=int, help = "add number of iteration", required=True)
parser.add_argument('-p', dest="precision", type=float, help = "add precision", required=True)
params = parser.parse_args()

try:
    res = newton(params.fun,params.x0,maxiter=params.step, tol=params.precision)
except Exception:
    res = newton(params.fun, params.x0, maxiter=params.step)

print(res)
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 12
#     params = parser.parse_args()
#
#   File ~\anaconda3\lib\argparse.py:1826 in parse_args
#     args, argv = self.parse_known_args(args, namespace)
#
#   File ~\anaconda3\lib\argparse.py:1859 in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#
#   File ~\anaconda3\lib\argparse.py:2072 in _parse_known_args
#     start_index = consume_optional(start_index)
#
#   File ~\anaconda3\lib\argparse.py:2012 in consume_optional
#     take_action(action, args, option_string)
#
#   File ~\anaconda3\lib\argparse.py:1920 in take_action
#     argument_values = self._get_values(action, argument_strings)
#
#   File ~\anaconda3\lib\argparse.py:2455 in _get_values
#     value = self._get_value(action, arg_string)
#
#   File ~\anaconda3\lib\argparse.py:2488 in _get_value
#     result = type_func(arg_string)
#
#   Cell In[1], line 5 in function
#     return eval(l)
#
#   File <string>:1
#     C:\Users\jakub\AppData\Roaming\jupyter\runtime\kernel-bea6d8f0-e09c-4c0b-b4dc-e853884a544e.json
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# `./newton.py x**2+x+1 -h 0.00001`

# %% [markdown]
# ## Zadanie 2

# %% [markdown]
# Zadanie należy wykonać wykorzystując program `BagOfWords` z poprzednich zajęć.
#
#
# Przerób ją tak, żeby interpunkcja, cyfry i wszelkie inne znaki nie przeszkadzały w parsowaniu tekstu. Uruchom ja na [tekście hamleta](http://www.gutenberg.org/cache/epub/1787/pg1787.txt). Ile razy występuje słowo hamlet? Jak brzmi 10 najczęściej występujących słów?

# %%
import re
from collections import Counter
class BagOfWords:

    def __init__(self, file):
        self.dic = {}
        if isinstance(file, str):
            try:
                file = open(file, encoding='utf-8').read().split('\n')
                for line in file:
                    line = line.split(' ')
                    for l in line:
                        if len(l) == 0: continue
                        l = l.lower()
                        l = re.sub(r'\'s','',l)
                        l = re.sub(r'[^a-z]','',l)
                        self.dic[l] = self.dic.get(l, 0) + 1
            except:
                self.dic = dict(Counter(file.split(' ')))

    def __contains__(self, elem):
        return self.dic.get(elem, 0)

    def __iter__(self):
        return iter(map(lambda x: x[0], sorted(self.dic.items(), key=lambda x: x[1], reverse=True)))

    def __str__(self):
        x = sorted(self.dic.items(), key=lambda x: x[1], reverse=True)
        z = ""
        for i in x:
            z += ':'.join((str(i[0]), str(i[1]))) + ", "
        return z[:-2]

    def __getitem__(self, key):
        return self.dic[key]

    def __add__(self, d):
        return {key: self.dic[key] + d.dic[key] if key in d.dic and key in self.dic else (self.dic[key]
                if key in self.dic else d.dic[key]) for key in {**self.dic, **d.dic}.keys()}

# %%
b = BagOfWords('hamlet.txt')
print(b)
print(b['hamlet'])
print(str(b).split(', ')[:10])
# Out:
# the:1349, and:1101, of:887, to:863, you:660, a:633, i:575, my:520, in:508, it:446, that:442, is:416, this:385, not:363, ham:358, with:341, for:334, his:304, but:282, your:270, be:266, or:259, as:257, me:234, lord:226, he:225, what:221, so:212, king:203, him:197, have:195, by:193, are:187, will:183, do:172, no:158, we:157, all:147, if:144, on:144, our:128, :127, o:126, hamlet:125, project:122, queen:121, from:117, shall:117, gutenberg:114, may:112, good:109, hor:109, at:108, come:108, let:106, thou:105, they:103, there:98, more:98, now:98, how:95, well:91, her:91, most:89, was:87, thy:86, pol:86, like:82, would:81, us:79, such:78, them:75, know:75, sir:75, which:73, enter:73, tis:73, any:72, must:72, th:72, go:71, father:70, give:69, very:67, then:66, did:66, love:66, hath:65, why:64, time:63, an:63, speak:63, here:63, ill:62, laer:62, where:61, when:60, should:60, thee:59, their:58, make:58, oph:58, work:57, upon:57, man:57, one:56, than:56, am:56, some:55, out:55, electronic:54, say:54, other:53, works:51, these:51, can:50, much:50, too:50, she:50, who:49, think:48, see:48, horatio:47, world:46, laertes:46, heaven:46, play:46, thus:45, mother:45, ros:45, had:44, up:43, tell:43, yet:43, use:42, exit:40, copyright:39, own:39, nor:38, both:37, take:37, night:37, look:37, death:37, exeunt:37, ay:37, polonius:36, clown:36, copies:35, ghost:35, god:35, soul:35, etext:34, cannot:34, again:34, life:34, long:33, made:33, hear:33, could:33, mar:32, might:32, whose:32, hold:31, nothing:31, dead:31, mine:31, indeed:31, distributed:30, guildenstern:30, ophelia:30, heart:30, set:30, away:29, about:29, does:29, into:29, within:29, down:29, part:29, dear:29, nature:29, guil:29, were:28, denmark:28, doth:28, been:28, pray:28, leave:28, terms:27, two:27, even:27, without:27, matter:27, before:26, rosencrantz:26, nay:26, great:26, never:26, against:25, comes:25, head:25, sweet:25, osr:25, those:24, scene:24, full:24, earth:24, though:24, itself:24, put:24, shakespeare:23, son:23, players:23, elsinore:23, eyes:23, show:23, means:23, service:22, day:22, form:22, seen:22, true:22, done:22, old:22, follow:22, call:22, madness:22, foundation:22, e:22, states:21, library:21, complete:21, only:21, first:21, end:21, many:21, off:21, fair:21, blood:21, himself:21, keep:21, mad:21, england:21, license:20, others:20, distribution:20, since:20, else:20, cause:20, ber:20, friends:20, fear:20, state:20, still:20, till:20, poor:20, words:20, william:19, provided:19, permission:19, donations:19, act:19, thing:19, once:19, believe:19, hand:19, aside:19, makes:19, used:18, welcome:18, ist:18, young:18, little:18, agreement:18, readable:17, free:17, please:17, right:17, farewell:17, art:17, find:17, thoughts:17, noble:17, body:17, ear:17, sword:17, version:16, charges:16, law:16, gentleman:16, daughter:16, live:16, question:16, majesty:16, hast:16, brother:16, faith:16, youth:16, marry:16, speech:16, fortune:16, ebook:15, united:15, copy:15, inc:15, has:15, machine:15, last:15, university:15, including:15, word:15, purpose:15, fortinbras:15, gertrude:15, castle:15, stand:15, yourself:15, watch:15, therefore:15, mark:15, eye:15, bear:15, better:15, tongue:15, drink:15, while:15, men:15, said:15, between:15, after:15, help:15, lady:15, personal:14, commercial:14, includes:14, further:14, trademark:14, each:14, ever:14, carnegie:14, mellon:14, second:14, kind:14, friend:14, answer:14, ho:14, charge:14, gone:14, something:14, goes:14, mind:14, heard:14, spirit:14, oer:14, grief:14, reason:14, thine:14, forth:14, gentlemen:14, phrase:14, another:14, murther:14, sent:14, rest:14, dost:14, sings:14, under:13, commercially:13, prohibited:13, download:13, membership:13, information:13, refund:13, norway:13, same:13, air:13, duty:13, room:13, ourselves:13, things:13, sense:13, grace:13, name:13, none:13, virtue:13, way:13, rey:13, literary:13, archive:13, almost:12, access:12, thousand:12, fee:12, receive:12, marcellus:12, haste:12, myself:12, together:12, stay:12, int:12, ...
# 125
# ['the:1349', 'and:1101', 'of:887', 'to:863', 'you:660', 'a:633', 'i:575', 'my:520', 'in:508', 'it:446']

# %% [markdown]
# ## Zadanie 3

# %% [markdown]
# Wykorzystując `pickle` zapisz i odczytaj klasy z poprzedniego zadania nakarmonej Hamletem. Porównaj metody i rozmiar.

# %%
import pickle
with open('hamlet.pickle','wb') as file:
    pickle.dump(b,file)
with open('hamlet.pickle', 'rb') as file:
    bag = pickle.load(file)
print(bag)
# Out:
# the:1349, and:1101, of:887, to:863, you:660, a:633, i:575, my:520, in:508, it:446, that:442, is:416, this:385, not:363, ham:358, with:341, for:334, his:304, but:282, your:270, be:266, or:259, as:257, me:234, lord:226, he:225, what:221, so:212, king:203, him:197, have:195, by:193, are:187, will:183, do:172, no:158, we:157, all:147, if:144, on:144, our:128, :127, o:126, hamlet:125, project:122, queen:121, from:117, shall:117, gutenberg:114, may:112, good:109, hor:109, at:108, come:108, let:106, thou:105, they:103, there:98, more:98, now:98, how:95, well:91, her:91, most:89, was:87, thy:86, pol:86, like:82, would:81, us:79, such:78, them:75, know:75, sir:75, which:73, enter:73, tis:73, any:72, must:72, th:72, go:71, father:70, give:69, very:67, then:66, did:66, love:66, hath:65, why:64, time:63, an:63, speak:63, here:63, ill:62, laer:62, where:61, when:60, should:60, thee:59, their:58, make:58, oph:58, work:57, upon:57, man:57, one:56, than:56, am:56, some:55, out:55, electronic:54, say:54, other:53, works:51, these:51, can:50, much:50, too:50, she:50, who:49, think:48, see:48, horatio:47, world:46, laertes:46, heaven:46, play:46, thus:45, mother:45, ros:45, had:44, up:43, tell:43, yet:43, use:42, exit:40, copyright:39, own:39, nor:38, both:37, take:37, night:37, look:37, death:37, exeunt:37, ay:37, polonius:36, clown:36, copies:35, ghost:35, god:35, soul:35, etext:34, cannot:34, again:34, life:34, long:33, made:33, hear:33, could:33, mar:32, might:32, whose:32, hold:31, nothing:31, dead:31, mine:31, indeed:31, distributed:30, guildenstern:30, ophelia:30, heart:30, set:30, away:29, about:29, does:29, into:29, within:29, down:29, part:29, dear:29, nature:29, guil:29, were:28, denmark:28, doth:28, been:28, pray:28, leave:28, terms:27, two:27, even:27, without:27, matter:27, before:26, rosencrantz:26, nay:26, great:26, never:26, against:25, comes:25, head:25, sweet:25, osr:25, those:24, scene:24, full:24, earth:24, though:24, itself:24, put:24, shakespeare:23, son:23, players:23, elsinore:23, eyes:23, show:23, means:23, service:22, day:22, form:22, seen:22, true:22, done:22, old:22, follow:22, call:22, madness:22, foundation:22, e:22, states:21, library:21, complete:21, only:21, first:21, end:21, many:21, off:21, fair:21, blood:21, himself:21, keep:21, mad:21, england:21, license:20, others:20, distribution:20, since:20, else:20, cause:20, ber:20, friends:20, fear:20, state:20, still:20, till:20, poor:20, words:20, william:19, provided:19, permission:19, donations:19, act:19, thing:19, once:19, believe:19, hand:19, aside:19, makes:19, used:18, welcome:18, ist:18, young:18, little:18, agreement:18, readable:17, free:17, please:17, right:17, farewell:17, art:17, find:17, thoughts:17, noble:17, body:17, ear:17, sword:17, version:16, charges:16, law:16, gentleman:16, daughter:16, live:16, question:16, majesty:16, hast:16, brother:16, faith:16, youth:16, marry:16, speech:16, fortune:16, ebook:15, united:15, copy:15, inc:15, has:15, machine:15, last:15, university:15, including:15, word:15, purpose:15, fortinbras:15, gertrude:15, castle:15, stand:15, yourself:15, watch:15, therefore:15, mark:15, eye:15, bear:15, better:15, tongue:15, drink:15, while:15, men:15, said:15, between:15, after:15, help:15, lady:15, personal:14, commercial:14, includes:14, further:14, trademark:14, each:14, ever:14, carnegie:14, mellon:14, second:14, kind:14, friend:14, answer:14, ho:14, charge:14, gone:14, something:14, goes:14, mind:14, heard:14, spirit:14, oer:14, grief:14, reason:14, thine:14, forth:14, gentlemen:14, phrase:14, another:14, murther:14, sent:14, rest:14, dost:14, sings:14, under:13, commercially:13, prohibited:13, download:13, membership:13, information:13, refund:13, norway:13, same:13, air:13, duty:13, room:13, ourselves:13, things:13, sense:13, grace:13, name:13, none:13, virtue:13, way:13, rey:13, literary:13, archive:13, almost:12, access:12, thousand:12, fee:12, receive:12, marcellus:12, haste:12, myself:12, together:12, stay:12, int:12, ...

# %% [markdown]
# ## Zadanie 4

# %% [markdown]
# Wykorzystując [https://gist.github.com/pamelafox/986163](https://gist.github.com/pamelafox/986163) podaj aktualną godzinę we:
# - wszystkich krajach, wyświetlając je zgrupowane względem kontynentów,
# - przeprowadź symulacyjne wyświetlanie kolejnych krajów w miarę jak w danym kraju wybija północ, opóżnienie wyświetlania ustaw proporcjonalne do realnego czasu

# %%
countries = [
{'timezones': ['Europe/Andorra'], 'code': 'AD', 'continent': 'Europe', 'name': 'Andorra', 'capital': 'Andorra la Vella'},
{'timezones': ['Asia/Kabul'], 'code': 'AF', 'continent': 'Asia', 'name': 'Afghanistan', 'capital': 'Kabul'},
{'timezones': ['America/Antigua'], 'code': 'AG', 'continent': 'North America', 'name': 'Antigua and Barbuda', 'capital': "St. John's"},
{'timezones': ['Europe/Tirane'], 'code': 'AL', 'continent': 'Europe', 'name': 'Albania', 'capital': 'Tirana'},
{'timezones': ['Asia/Yerevan'], 'code': 'AM', 'continent': 'Asia', 'name': 'Armenia', 'capital': 'Yerevan'},
{'timezones': ['Africa/Luanda'], 'code': 'AO', 'continent': 'Africa', 'name': 'Angola', 'capital': 'Luanda'},
{'timezones': ['America/Argentina/Buenos_Aires', 'America/Argentina/Cordoba', 'America/Argentina/Jujuy', 'America/Argentina/Tucuman', 'America/Argentina/Catamarca', 'America/Argentina/La_Rioja', 'America/Argentina/San_Juan', 'America/Argentina/Mendoza', 'America/Argentina/Rio_Gallegos', 'America/Argentina/Ushuaia'], 'code': 'AR', 'continent': 'South America', 'name': 'Argentina', 'capital': 'Buenos Aires'},
{'timezones': ['Europe/Vienna'], 'code': 'AT', 'continent': 'Europe', 'name': 'Austria', 'capital': 'Vienna'},
{'timezones': ['Australia/Lord_Howe', 'Australia/Hobart', 'Australia/Currie', 'Australia/Melbourne', 'Australia/Sydney', 'Australia/Broken_Hill', 'Australia/Brisbane', 'Australia/Lindeman', 'Australia/Adelaide', 'Australia/Darwin', 'Australia/Perth'], 'code': 'AU', 'continent': 'Oceania', 'name': 'Australia', 'capital': 'Canberra'},
{'timezones': ['Asia/Baku'], 'code': 'AZ', 'continent': 'Asia', 'name': 'Azerbaijan', 'capital': 'Baku'},
{'timezones': ['America/Barbados'], 'code': 'BB', 'continent': 'North America', 'name': 'Barbados', 'capital': 'Bridgetown'},
{'timezones': ['Asia/Dhaka'], 'code': 'BD', 'continent': 'Asia', 'name': 'Bangladesh', 'capital': 'Dhaka'},
{'timezones': ['Europe/Brussels'], 'code': 'BE', 'continent': 'Europe', 'name': 'Belgium', 'capital': 'Brussels'},
{'timezones': ['Africa/Ouagadougou'], 'code': 'BF', 'continent': 'Africa', 'name': 'Burkina Faso', 'capital': 'Ouagadougou'},
{'timezones': ['Europe/Sofia'], 'code': 'BG', 'continent': 'Europe', 'name': 'Bulgaria', 'capital': 'Sofia'},
{'timezones': ['Asia/Bahrain'], 'code': 'BH', 'continent': 'Asia', 'name': 'Bahrain', 'capital': 'Manama'},
{'timezones': ['Africa/Bujumbura'], 'code': 'BI', 'continent': 'Africa', 'name': 'Burundi', 'capital': 'Bujumbura'},
{'timezones': ['Africa/Porto-Novo'], 'code': 'BJ', 'continent': 'Africa', 'name': 'Benin', 'capital': 'Porto-Novo'},
{'timezones': ['Asia/Brunei'], 'code': 'BN', 'continent': 'Asia', 'name': 'Brunei Darussalam', 'capital': 'Bandar Seri Begawan'},
{'timezones': ['America/La_Paz'], 'code': 'BO', 'continent': 'South America', 'name': 'Bolivia', 'capital': 'Sucre'},
{'timezones': ['America/Noronha', 'America/Belem', 'America/Fortaleza', 'America/Recife', 'America/Araguaina', 'America/Maceio', 'America/Bahia', 'America/Sao_Paulo', 'America/Campo_Grande', 'America/Cuiaba', 'America/Porto_Velho', 'America/Boa_Vista', 'America/Manaus', 'America/Eirunepe', 'America/Rio_Branco'], 'code': 'BR', 'continent': 'South America', 'name': 'Brazil', 'capital': 'Bras\xc3\xadlia'},
{'timezones': ['America/Nassau'], 'code': 'BS', 'continent': 'North America', 'name': 'Bahamas', 'capital': 'Nassau'},
{'timezones': ['Asia/Thimphu'], 'code': 'BT', 'continent': 'Asia', 'name': 'Bhutan', 'capital': 'Thimphu'},
{'timezones': ['Africa/Gaborone'], 'code': 'BW', 'continent': 'Africa', 'name': 'Botswana', 'capital': 'Gaborone'},
{'timezones': ['Europe/Minsk'], 'code': 'BY', 'continent': 'Europe', 'name': 'Belarus', 'capital': 'Minsk'},
{'timezones': ['America/Belize'], 'code': 'BZ', 'continent': 'North America', 'name': 'Belize', 'capital': 'Belmopan'},
{'timezones': ['America/St_Johns', 'America/Halifax', 'America/Glace_Bay', 'America/Moncton', 'America/Goose_Bay', 'America/Blanc-Sablon', 'America/Montreal', 'America/Toronto', 'America/Nipigon', 'America/Thunder_Bay', 'America/Pangnirtung', 'America/Iqaluit', 'America/Atikokan', 'America/Rankin_Inlet', 'America/Winnipeg', 'America/Rainy_River', 'America/Cambridge_Bay', 'America/Regina', 'America/Swift_Current', 'America/Edmonton', 'America/Yellowknife', 'America/Inuvik', 'America/Dawson_Creek', 'America/Vancouver', 'America/Whitehorse', 'America/Dawson'], 'code': 'CA', 'continent': 'North America', 'name': 'Canada', 'capital': 'Ottawa'},
{'timezones': ['Africa/Kinshasa', 'Africa/Lubumbashi'], 'code': 'CD', 'continent': 'Africa', 'name': 'Democratic Republic of the Congo', 'capital': 'Kinshasa'},
{'timezones': ['Africa/Brazzaville'], 'code': 'CG', 'continent': 'Africa', 'name': 'Republic of the Congo', 'capital': 'Brazzaville'},
{'timezones': ['Africa/Abidjan'], 'code': 'CI', 'continent': 'Africa', 'name': "C\xc3\xb4te d'Ivoire", 'capital': 'Yamoussoukro'},
{'timezones': ['America/Santiago', 'Pacific/Easter'], 'code': 'CL', 'continent': 'South America', 'name': 'Chile', 'capital': 'Santiago'},
{'timezones': ['Africa/Douala'], 'code': 'CM', 'continent': 'Africa', 'name': 'Cameroon', 'capital': 'Yaound\xc3\xa9'},
{'timezones': ['Asia/Shanghai', 'Asia/Harbin', 'Asia/Chongqing', 'Asia/Urumqi', 'Asia/Kashgar'], 'code': 'CN', 'continent': 'Asia', 'name': "People's Republic of China", 'capital': 'Beijing'},
{'timezones': ['America/Bogota'], 'code': 'CO', 'continent': 'South America', 'name': 'Colombia', 'capital': 'Bogot\xc3\xa1'},
{'timezones': ['America/Costa_Rica'], 'code': 'CR', 'continent': 'North America', 'name': 'Costa Rica', 'capital': 'San Jos\xc3\xa9'},
{'timezones': ['America/Havana'], 'code': 'CU', 'continent': 'North America', 'name': 'Cuba', 'capital': 'Havana'},
{'timezones': ['Atlantic/Cape_Verde'], 'code': 'CV', 'continent': 'Africa', 'name': 'Cape Verde', 'capital': 'Praia'},
{'timezones': ['Asia/Nicosia'], 'code': 'CY', 'continent': 'Asia', 'name': 'Cyprus', 'capital': 'Nicosia'},
{'timezones': ['Europe/Prague'], 'code': 'CZ', 'continent': 'Europe', 'name': 'Czech Republic', 'capital': 'Prague'},
{'timezones': ['Europe/Berlin'], 'code': 'DE', 'continent': 'Europe', 'name': 'Germany', 'capital': 'Berlin'},
{'timezones': ['Africa/Djibouti'], 'code': 'DJ', 'continent': 'Africa', 'name': 'Djibouti', 'capital': 'Djibouti City'},
{'timezones': ['Europe/Copenhagen'], 'code': 'DK', 'continent': 'Europe', 'name': 'Denmark', 'capital': 'Copenhagen'},
{'timezones': ['America/Dominica'], 'code': 'DM', 'continent': 'North America', 'name': 'Dominica', 'capital': 'Roseau'},
{'timezones': ['America/Santo_Domingo'], 'code': 'DO', 'continent': 'North America', 'name': 'Dominican Republic', 'capital': 'Santo Domingo'},
{'timezones': ['America/Guayaquil', 'Pacific/Galapagos'], 'code': 'EC', 'continent': 'South America', 'name': 'Ecuador', 'capital': 'Quito'},
{'timezones': ['Europe/Tallinn'], 'code': 'EE', 'continent': 'Europe', 'name': 'Estonia', 'capital': 'Tallinn'},
{'timezones': ['Africa/Cairo'], 'code': 'EG', 'continent': 'Africa', 'name': 'Egypt', 'capital': 'Cairo'},
{'timezones': ['Africa/Asmera'], 'code': 'ER', 'continent': 'Africa', 'name': 'Eritrea', 'capital': 'Asmara'},
{'timezones': ['Africa/Addis_Ababa'], 'code': 'ET', 'continent': 'Africa', 'name': 'Ethiopia', 'capital': 'Addis Ababa'},
{'timezones': ['Europe/Helsinki'], 'code': 'FI', 'continent': 'Europe', 'name': 'Finland', 'capital': 'Helsinki'},
{'timezones': ['Pacific/Fiji'], 'code': 'FJ', 'continent': 'Oceania', 'name': 'Fiji', 'capital': 'Suva'},
{'timezones': ['Europe/Paris'], 'code': 'FR', 'continent': 'Europe', 'name': 'France', 'capital': 'Paris'},
{'timezones': ['Africa/Libreville'], 'code': 'GA', 'continent': 'Africa', 'name': 'Gabon', 'capital': 'Libreville'},
{'timezones': ['Asia/Tbilisi'], 'code': 'GE', 'continent': 'Asia', 'name': 'Georgia', 'capital': 'Tbilisi'},
{'timezones': ['Africa/Accra'], 'code': 'GH', 'continent': 'Africa', 'name': 'Ghana', 'capital': 'Accra'},
{'timezones': ['Africa/Banjul'], 'code': 'GM', 'continent': 'Africa', 'name': 'The Gambia', 'capital': 'Banjul'},
{'timezones': ['Africa/Conakry'], 'code': 'GN', 'continent': 'Africa', 'name': 'Guinea', 'capital': 'Conakry'},
{'timezones': ['Europe/Athens'], 'code': 'GR', 'continent': 'Europe', 'name': 'Greece', 'capital': 'Athens'},
{'timezones': ['America/Guatemala'], 'code': 'GT', 'continent': 'North America', 'name': 'Guatemala', 'capital': 'Guatemala City'},
{'timezones': ['America/Guatemala'], 'code': 'GT', 'continent': 'North America', 'name': 'Haiti', 'capital': 'Port-au-Prince'},
{'timezones': ['Africa/Bissau'], 'code': 'GW', 'continent': 'Africa', 'name': 'Guinea-Bissau', 'capital': 'Bissau'},
{'timezones': ['America/Guyana'], 'code': 'GY', 'continent': 'South America', 'name': 'Guyana', 'capital': 'Georgetown'},
{'timezones': ['America/Tegucigalpa'], 'code': 'HN', 'continent': 'North America', 'name': 'Honduras', 'capital': 'Tegucigalpa'},
{'timezones': ['Europe/Budapest'], 'code': 'HU', 'continent': 'Europe', 'name': 'Hungary', 'capital': 'Budapest'},
{'timezones': ['Asia/Jakarta', 'Asia/Pontianak', 'Asia/Makassar', 'Asia/Jayapura'], 'code': 'ID', 'continent': 'Asia', 'name': 'Indonesia', 'capital': 'Jakarta'},
{'timezones': ['Europe/Dublin'], 'code': 'IE', 'continent': 'Europe', 'name': 'Republic of Ireland', 'capital': 'Dublin'},
{'timezones': ['Asia/Jerusalem'], 'code': 'IL', 'continent': 'Asia', 'name': 'Israel', 'capital': 'Jerusalem'},
{'timezones': ['Asia/Calcutta'], 'code': 'IN', 'continent': 'Asia', 'name': 'India', 'capital': 'New Delhi'},
{'timezones': ['Asia/Baghdad'], 'code': 'IQ', 'continent': 'Asia', 'name': 'Iraq', 'capital': 'Baghdad'},
{'timezones': ['Asia/Tehran'], 'code': 'IR', 'continent': 'Asia', 'name': 'Iran', 'capital': 'Tehran'},
{'timezones': ['Atlantic/Reykjavik'], 'code': 'IS', 'continent': 'Europe', 'name': 'Iceland', 'capital': 'Reykjav\xc3\xadk'},
{'timezones': ['Europe/Rome'], 'code': 'IT', 'continent': 'Europe', 'name': 'Italy', 'capital': 'Rome'},
{'timezones': ['America/Jamaica'], 'code': 'JM', 'continent': 'North America', 'name': 'Jamaica', 'capital': 'Kingston'},
{'timezones': ['Asia/Amman'], 'code': 'JO', 'continent': 'Asia', 'name': 'Jordan', 'capital': 'Amman'},
{'timezones': ['Asia/Tokyo'], 'code': 'JP', 'continent': 'Asia', 'name': 'Japan', 'capital': 'Tokyo'},
{'timezones': ['Africa/Nairobi'], 'code': 'KE', 'continent': 'Africa', 'name': 'Kenya', 'capital': 'Nairobi'},
{'timezones': ['Asia/Bishkek'], 'code': 'KG', 'continent': 'Asia', 'name': 'Kyrgyzstan', 'capital': 'Bishkek'},
{'timezones': ['Pacific/Tarawa', 'Pacific/Enderbury', 'Pacific/Kiritimati'], 'code': 'KI', 'continent': 'Oceania', 'name': 'Kiribati', 'capital': 'Tarawa'},
{'timezones': ['Asia/Pyongyang'], 'code': 'KP', 'continent': 'Asia', 'name': 'North Korea', 'capital': 'Pyongyang'},
{'timezones': ['Asia/Seoul'], 'code': 'KR', 'continent': 'Asia', 'name': 'South Korea', 'capital': 'Seoul'},
{'timezones': ['Asia/Kuwait'], 'code': 'KW', 'continent': 'Asia', 'name': 'Kuwait', 'capital': 'Kuwait City'},
{'timezones': ['Asia/Beirut'], 'code': 'LB', 'continent': 'Asia', 'name': 'Lebanon', 'capital': 'Beirut'},
{'timezones': ['Europe/Vaduz'], 'code': 'LI', 'continent': 'Europe', 'name': 'Liechtenstein', 'capital': 'Vaduz'},
{'timezones': ['Africa/Monrovia'], 'code': 'LR', 'continent': 'Africa', 'name': 'Liberia', 'capital': 'Monrovia'},
{'timezones': ['Africa/Maseru'], 'code': 'LS', 'continent': 'Africa', 'name': 'Lesotho', 'capital': 'Maseru'},
{'timezones': ['Europe/Vilnius'], 'code': 'LT', 'continent': 'Europe', 'name': 'Lithuania', 'capital': 'Vilnius'},
{'timezones': ['Europe/Luxembourg'], 'code': 'LU', 'continent': 'Europe', 'name': 'Luxembourg', 'capital': 'Luxembourg City'},
{'timezones': ['Europe/Riga'], 'code': 'LV', 'continent': 'Europe', 'name': 'Latvia', 'capital': 'Riga'},
{'timezones': ['Africa/Tripoli'], 'code': 'LY', 'continent': 'Africa', 'name': 'Libya', 'capital': 'Tripoli'},
{'timezones': ['Indian/Antananarivo'], 'code': 'MG', 'continent': 'Africa', 'name': 'Madagascar', 'capital': 'Antananarivo'},
{'timezones': ['Pacific/Majuro', 'Pacific/Kwajalein'], 'code': 'MH', 'continent': 'Oceania', 'name': 'Marshall Islands', 'capital': 'Majuro'},
{'timezones': ['Europe/Skopje'], 'code': 'MK', 'continent': 'Europe', 'name': 'Macedonia', 'capital': 'Skopje'},
{'timezones': ['Africa/Bamako'], 'code': 'ML', 'continent': 'Africa', 'name': 'Mali', 'capital': 'Bamako'},
{'timezones': ['Asia/Rangoon'], 'code': 'MM', 'continent': 'Asia', 'name': 'Myanmar', 'capital': 'Naypyidaw'},
{'timezones': ['Asia/Ulaanbaatar', 'Asia/Hovd', 'Asia/Choibalsan'], 'code': 'MN', 'continent': 'Asia', 'name': 'Mongolia', 'capital': 'Ulaanbaatar'},
{'timezones': ['Africa/Nouakchott'], 'code': 'MR', 'continent': 'Africa', 'name': 'Mauritania', 'capital': 'Nouakchott'},
{'timezones': ['Europe/Malta'], 'code': 'MT', 'continent': 'Europe', 'name': 'Malta', 'capital': 'Valletta'},
{'timezones': ['Indian/Mauritius'], 'code': 'MU', 'continent': 'Africa', 'name': 'Mauritius', 'capital': 'Port Louis'},
{'timezones': ['Indian/Maldives'], 'code': 'MV', 'continent': 'Asia', 'name': 'Maldives', 'capital': 'Mal\xc3\xa9'},
{'timezones': ['Africa/Blantyre'], 'code': 'MW', 'continent': 'Africa', 'name': 'Malawi', 'capital': 'Lilongwe'},
{'timezones': ['America/Mexico_City', 'America/Cancun', 'America/Merida', 'America/Monterrey', 'America/Mazatlan', 'America/Chihuahua', 'America/Hermosillo', 'America/Tijuana'], 'code': 'MX', 'continent': 'North America', 'name': 'Mexico', 'capital': 'Mexico City'},
{'timezones': ['Asia/Kuala_Lumpur', 'Asia/Kuching'], 'code': 'MY', 'continent': 'Asia', 'name': 'Malaysia', 'capital': 'Kuala Lumpur'},
{'timezones': ['Africa/Maputo'], 'code': 'MZ', 'continent': 'Africa', 'name': 'Mozambique', 'capital': 'Maputo'},
{'timezones': ['Africa/Windhoek'], 'code': 'NA', 'continent': 'Africa', 'name': 'Namibia', 'capital': 'Windhoek'},
{'timezones': ['Africa/Niamey'], 'code': 'NE', 'continent': 'Africa', 'name': 'Niger', 'capital': 'Niamey'},
{'timezones': ['Africa/Lagos'], 'code': 'NG', 'continent': 'Africa', 'name': 'Nigeria', 'capital': 'Abuja'},
{'timezones': ['America/Managua'], 'code': 'NI', 'continent': 'North America', 'name': 'Nicaragua', 'capital': 'Managua'},
{'timezones': ['Europe/Amsterdam'], 'code': 'NL', 'continent': 'Europe', 'name': 'Kingdom of the Netherlands', 'capital': 'Amsterdam'},
{'timezones': ['Europe/Oslo'], 'code': 'NO', 'continent': 'Europe', 'name': 'Norway', 'capital': 'Oslo'},
{'timezones': ['Asia/Katmandu'], 'code': 'NP', 'continent': 'Asia', 'name': 'Nepal', 'capital': 'Kathmandu'},
{'timezones': ['Pacific/Nauru'], 'code': 'NR', 'continent': 'Oceania', 'name': 'Nauru', 'capital': 'Yaren'},
{'timezones': ['Pacific/Auckland', 'Pacific/Chatham'], 'code': 'NZ', 'continent': 'Oceania', 'name': 'New Zealand', 'capital': 'Wellington'},
{'timezones': ['Asia/Muscat'], 'code': 'OM', 'continent': 'Asia', 'name': 'Oman', 'capital': 'Muscat'},
{'timezones': ['America/Panama'], 'code': 'PA', 'continent': 'North America', 'name': 'Panama', 'capital': 'Panama City'},
{'timezones': ['America/Lima'], 'code': 'PE', 'continent': 'South America', 'name': 'Peru', 'capital': 'Lima'},
{'timezones': ['Pacific/Port_Moresby'], 'code': 'PG', 'continent': 'Oceania', 'name': 'Papua New Guinea', 'capital': 'Port Moresby'},
{'timezones': ['Asia/Manila'], 'code': 'PH', 'continent': 'Asia', 'name': 'Philippines', 'capital': 'Manila'},
{'timezones': ['Asia/Karachi'], 'code': 'PK', 'continent': 'Asia', 'name': 'Pakistan', 'capital': 'Islamabad'},
{'timezones': ['Europe/Warsaw'], 'code': 'PL', 'continent': 'Europe', 'name': 'Poland', 'capital': 'Warsaw'},
{'timezones': ['Europe/Lisbon', 'Atlantic/Madeira', 'Atlantic/Azores'], 'code': 'PT', 'continent': 'Europe', 'name': 'Portugal', 'capital': 'Lisbon'},
{'timezones': ['Pacific/Palau'], 'code': 'PW', 'continent': 'Oceania', 'name': 'Palau', 'capital': 'Ngerulmud'},
{'timezones': ['America/Asuncion'], 'code': 'PY', 'continent': 'South America', 'name': 'Paraguay', 'capital': 'Asunci\xc3\xb3n'},
{'timezones': ['Asia/Qatar'], 'code': 'QA', 'continent': 'Asia', 'name': 'Qatar', 'capital': 'Doha'},
{'timezones': ['Europe/Bucharest'], 'code': 'RO', 'continent': 'Europe', 'name': 'Romania', 'capital': 'Bucharest'},
{'timezones': ['Europe/Kaliningrad', 'Europe/Moscow', 'Europe/Volgograd', 'Europe/Samara', 'Asia/Yekaterinburg', 'Asia/Omsk', 'Asia/Novosibirsk', 'Asia/Krasnoyarsk', 'Asia/Irkutsk', 'Asia/Yakutsk', 'Asia/Vladivostok', 'Asia/Sakhalin', 'Asia/Magadan', 'Asia/Kamchatka', 'Asia/Anadyr'], 'code': 'RU', 'continent': 'Europe', 'name': 'Russia', 'capital': 'Moscow'},
{'timezones': ['Africa/Kigali'], 'code': 'RW', 'continent': 'Africa', 'name': 'Rwanda', 'capital': 'Kigali'},
{'timezones': ['Asia/Riyadh'], 'code': 'SA', 'continent': 'Asia', 'name': 'Saudi Arabia', 'capital': 'Riyadh'},
{'timezones': ['Pacific/Guadalcanal'], 'code': 'SB', 'continent': 'Oceania', 'name': 'Solomon Islands', 'capital': 'Honiara'},
{'timezones': ['Indian/Mahe'], 'code': 'SC', 'continent': 'Africa', 'name': 'Seychelles', 'capital': 'Victoria'},
{'timezones': ['Africa/Khartoum'], 'code': 'SD', 'continent': 'Africa', 'name': 'Sudan', 'capital': 'Khartoum'},
{'timezones': ['Europe/Stockholm'], 'code': 'SE', 'continent': 'Europe', 'name': 'Sweden', 'capital': 'Stockholm'},
{'timezones': ['Asia/Singapore'], 'code': 'SG', 'continent': 'Asia', 'name': 'Singapore', 'capital': 'Singapore'},
{'timezones': ['Europe/Ljubljana'], 'code': 'SI', 'continent': 'Europe', 'name': 'Slovenia', 'capital': 'Ljubljana'},
{'timezones': ['Europe/Bratislava'], 'code': 'SK', 'continent': 'Europe', 'name': 'Slovakia', 'capital': 'Bratislava'},
{'timezones': ['Africa/Freetown'], 'code': 'SL', 'continent': 'Africa', 'name': 'Sierra Leone', 'capital': 'Freetown'},
{'timezones': ['Europe/San_Marino'], 'code': 'SM', 'continent': 'Europe', 'name': 'San Marino', 'capital': 'San Marino'},
{'timezones': ['Africa/Dakar'], 'code': 'SN', 'continent': 'Africa', 'name': 'Senegal', 'capital': 'Dakar'},
{'timezones': ['Africa/Mogadishu'], 'code': 'SO', 'continent': 'Africa', 'name': 'Somalia', 'capital': 'Mogadishu'},
{'timezones': ['America/Paramaribo'], 'code': 'SR', 'continent': 'South America', 'name': 'Suriname', 'capital': 'Paramaribo'},
{'timezones': ['Africa/Sao_Tome'], 'code': 'ST', 'continent': 'Africa', 'name': 'S\xc3\xa3o Tom\xc3\xa9 and Pr\xc3\xadncipe', 'capital': 'S\xc3\xa3o Tom\xc3\xa9'},
{'timezones': ['Asia/Damascus'], 'code': 'SY', 'continent': 'Asia', 'name': 'Syria', 'capital': 'Damascus'},
{'timezones': ['Africa/Lome'], 'code': 'TG', 'continent': 'Africa', 'name': 'Togo', 'capital': 'Lom\xc3\xa9'},
{'timezones': ['Asia/Bangkok'], 'code': 'TH', 'continent': 'Asia', 'name': 'Thailand', 'capital': 'Bangkok'},
{'timezones': ['Asia/Dushanbe'], 'code': 'TJ', 'continent': 'Asia', 'name': 'Tajikistan', 'capital': 'Dushanbe'},
{'timezones': ['Asia/Ashgabat'], 'code': 'TM', 'continent': 'Asia', 'name': 'Turkmenistan', 'capital': 'Ashgabat'},
{'timezones': ['Africa/Tunis'], 'code': 'TN', 'continent': 'Africa', 'name': 'Tunisia', 'capital': 'Tunis'},
{'timezones': ['Pacific/Tongatapu'], 'code': 'TO', 'continent': 'Oceania', 'name': 'Tonga', 'capital': 'Nuku\xca\xbbalofa'},
{'timezones': ['Europe/Istanbul'], 'code': 'TR', 'continent': 'Asia', 'name': 'Turkey', 'capital': 'Ankara'},
{'timezones': ['America/Port_of_Spain'], 'code': 'TT', 'continent': 'North America', 'name': 'Trinidad and Tobago', 'capital': 'Port of Spain'},
{'timezones': ['Pacific/Funafuti'], 'code': 'TV', 'continent': 'Oceania', 'name': 'Tuvalu', 'capital': 'Funafuti'},
{'timezones': ['Africa/Dar_es_Salaam'], 'code': 'TZ', 'continent': 'Africa', 'name': 'Tanzania', 'capital': 'Dodoma'},
{'timezones': ['Europe/Kiev', 'Europe/Uzhgorod', 'Europe/Zaporozhye', 'Europe/Simferopol'], 'code': 'UA', 'continent': 'Europe', 'name': 'Ukraine', 'capital': 'Kyiv'},
{'timezones': ['Africa/Kampala'], 'code': 'UG', 'continent': 'Africa', 'name': 'Uganda', 'capital': 'Kampala'},
{'timezones': ['America/New_York', 'America/Detroit', 'America/Kentucky/Louisville', 'America/Kentucky/Monticello', 'America/Indiana/Indianapolis', 'America/Indiana/Marengo', 'America/Indiana/Knox', 'America/Indiana/Vevay', 'America/Chicago', 'America/Indiana/Vincennes', 'America/Indiana/Petersburg', 'America/Menominee', 'America/North_Dakota/Center', 'America/North_Dakota/New_Salem', 'America/Denver', 'America/Boise', 'America/Shiprock', 'America/Phoenix', 'America/Los_Angeles', 'America/Anchorage', 'America/Juneau', 'America/Yakutat', 'America/Nome', 'America/Adak', 'Pacific/Honolulu'], 'code': 'US', 'continent': 'North America', 'name': 'United States', 'capital': 'Washington, D.C.'},
{'timezones': ['America/Montevideo'], 'code': 'UY', 'continent': 'South America', 'name': 'Uruguay', 'capital': 'Montevideo'},
{'timezones': ['Asia/Samarkand', 'Asia/Tashkent'], 'code': 'UZ', 'continent': 'Asia', 'name': 'Uzbekistan', 'capital': 'Tashkent'},
{'timezones': ['Europe/Vatican'], 'code': 'VA', 'continent': 'Europe', 'name': 'Vatican City', 'capital': 'Vatican City'},
{'timezones': ['America/Caracas'], 'code': 'VE', 'continent': 'South America', 'name': 'Venezuela', 'capital': 'Caracas'},
{'timezones': ['Asia/Saigon'], 'code': 'VN', 'continent': 'Asia', 'name': 'Vietnam', 'capital': 'Hanoi'},
{'timezones': ['Pacific/Efate'], 'code': 'VU', 'continent': 'Oceania', 'name': 'Vanuatu', 'capital': 'Port Vila'},
{'timezones': ['Asia/Aden'], 'code': 'YE', 'continent': 'Asia', 'name': 'Yemen', 'capital': "Sana'a"},
{'timezones': ['Africa/Lusaka'], 'code': 'ZM', 'continent': 'Africa', 'name': 'Zambia', 'capital': 'Lusaka'},
{'timezones': ['Africa/Harare'], 'code': 'ZW', 'continent': 'Africa', 'name': 'Zimbabwe', 'capital': 'Harare'},
{'timezones': ['Africa/Algiers'], 'code': 'DZ', 'continent': 'Africa', 'name': 'Algeria', 'capital': 'Algiers'},
{'timezones': ['Europe/Sarajevo'], 'code': 'BA', 'continent': 'Europe', 'name': 'Bosnia and Herzegovina', 'capital': 'Sarajevo'},
{'timezones': ['Asia/Phnom_Penh'], 'code': 'KH', 'continent': 'Asia', 'name': 'Cambodia', 'capital': 'Phnom Penh'},
{'timezones': ['Africa/Bangui'], 'code': 'CF', 'continent': 'Africa', 'name': 'Central African Republic', 'capital': 'Bangui'},
{'timezones': ['Africa/Ndjamena'], 'code': 'TD', 'continent': 'Africa', 'name': 'Chad', 'capital': "N'Djamena"},
{'timezones': ['Indian/Comoro'], 'code': 'KM', 'continent': 'Africa', 'name': 'Comoros', 'capital': 'Moroni'},
{'timezones': ['Europe/Zagreb'], 'code': 'HR', 'continent': 'Europe', 'name': 'Croatia', 'capital': 'Zagreb'},
{'timezones': ['Asia/Dili'], 'code': 'TL', 'continent': 'Asia', 'name': 'East Timor', 'capital': 'Dili'},
{'timezones': ['America/El_Salvador'], 'code': 'SV', 'continent': 'North America', 'name': 'El Salvador', 'capital': 'San Salvador'},
{'timezones': ['Africa/Malabo'], 'code': 'GQ', 'continent': 'Africa', 'name': 'Equatorial Guinea', 'capital': 'Malabo'},
{'timezones': ['America/Grenada'], 'code': 'GD', 'continent': 'North America', 'name': 'Grenada', 'capital': "St. George's"},
{'timezones': ['Asia/Almaty', 'Asia/Qyzylorda', 'Asia/Aqtobe', 'Asia/Aqtau', 'Asia/Oral'], 'code': 'KZ', 'continent': 'Asia', 'name': 'Kazakhstan', 'capital': 'Astana'},
{'timezones': ['Asia/Vientiane'], 'code': 'LA', 'continent': 'Asia', 'name': 'Laos', 'capital': 'Vientiane'},
{'timezones': ['Pacific/Truk', 'Pacific/Ponape', 'Pacific/Kosrae'], 'code': 'FM', 'continent': 'Oceania', 'name': 'Federated States of Micronesia', 'capital': 'Palikir'},
{'timezones': ['Europe/Chisinau'], 'code': 'MD', 'continent': 'Europe', 'name': 'Moldova', 'capital': 'Chi\xc5\x9fin\xc4\x83u'},
{'timezones': ['Europe/Monaco'], 'code': 'MC', 'continent': 'Europe', 'name': 'Monaco', 'capital': 'Monaco'},
{'timezones': ['Europe/Podgorica'], 'code': 'ME', 'continent': 'Europe', 'name': 'Montenegro', 'capital': 'Podgorica'},
{'timezones': ['Africa/Casablanca'], 'code': 'MA', 'continent': 'Africa', 'name': 'Morocco', 'capital': 'Rabat'},
{'timezones': ['America/St_Kitts'], 'code': 'KN', 'continent': 'North America', 'name': 'Saint Kitts and Nevis', 'capital': 'Basseterre'},
{'timezones': ['America/St_Lucia'], 'code': 'LC', 'continent': 'North America', 'name': 'Saint Lucia', 'capital': 'Castries'},
{'timezones': ['America/St_Vincent'], 'code': 'VC', 'continent': 'North America', 'name': 'Saint Vincent and the Grenadines', 'capital': 'Kingstown'},
{'timezones': ['Pacific/Apia'], 'code': 'WS', 'continent': 'Oceania', 'name': 'Samoa', 'capital': 'Apia'},
{'timezones': ['Europe/Belgrade'], 'code': 'RS', 'continent': 'Europe', 'name': 'Serbia', 'capital': 'Belgrade'},
{'timezones': ['Africa/Johannesburg'], 'code': 'ZA', 'continent': 'Africa', 'name': 'South Africa', 'capital': 'Pretoria'},
{'timezones': ['Europe/Madrid', 'Africa/Ceuta', 'Atlantic/Canary'], 'code': 'ES', 'continent': 'Europe', 'name': 'Spain', 'capital': 'Madrid'},
{'timezones': ['Asia/Colombo'], 'code': 'LK', 'continent': 'Asia', 'name': 'Sri Lanka', 'capital': 'Sri Jayewardenepura Kotte'},
{'timezones': ['Africa/Mbabane'], 'code': 'SZ', 'continent': 'Africa', 'name': 'Swaziland', 'capital': 'Mbabane'},
{'timezones': ['Europe/Zurich'], 'code': 'CH', 'continent': 'Europe', 'name': 'Switzerland', 'capital': 'Bern'},
{'timezones': ['Asia/Dubai'], 'code': 'AE', 'continent': 'Asia', 'name': 'United Arab Emirates', 'capital': 'Abu Dhabi'},
{'timezones': ['Europe/London'], 'code': 'GB', 'continent': 'Europe', 'name': 'United Kingdom', 'capital': 'London'},
]

# %%
from datetime import datetime
import pytz
countries = sorted(countries,key=lambda x: (x['continent'],x['name']))
continent = ""
dic = dict()
for x in countries:
    new_continent = x['continent']
    if new_continent != continent:
        continent = new_continent
        print(continent)
    print(f"     {x['name']}")
    for zone in x['timezones']:
        IST = pytz.timezone(zone)
        time = datetime.now(IST)
        hour = hour = time.strftime('%H')
        print(f"          {zone.split('/')[1]}: {time.strftime('%Y:%m:%d %H:%M:%S')}")
        if hour not in dic.keys():
            dic[hour] = []
        dic[hour].append((x['name'],zone.split('/')[1]))
# Out:
# Africa
#      Algeria
#           Algiers: 2023:12:01 13:42:49
#      Angola
#           Luanda: 2023:12:01 13:42:49
#      Benin
#           Porto-Novo: 2023:12:01 13:42:49
#      Botswana
#           Gaborone: 2023:12:01 14:42:49
#      Burkina Faso
#           Ouagadougou: 2023:12:01 12:42:49
#      Burundi
#           Bujumbura: 2023:12:01 14:42:49
#      Cameroon
#           Douala: 2023:12:01 13:42:49
#      Cape Verde
#           Cape_Verde: 2023:12:01 11:42:49
#      Central African Republic
#           Bangui: 2023:12:01 13:42:49
#      Chad
#           Ndjamena: 2023:12:01 13:42:49
#      Comoros
#           Comoro: 2023:12:01 15:42:49
#      CÃ´te d'Ivoire
#           Abidjan: 2023:12:01 12:42:49
#      Democratic Republic of the Congo
#           Kinshasa: 2023:12:01 13:42:49
#           Lubumbashi: 2023:12:01 14:42:49
#      Djibouti
#           Djibouti: 2023:12:01 15:42:49
#      Egypt
#           Cairo: 2023:12:01 14:42:49
#      Equatorial Guinea
#           Malabo: 2023:12:01 13:42:49
#      Eritrea
#           Asmera: 2023:12:01 15:42:49
#      Ethiopia
#           Addis_Ababa: 2023:12:01 15:42:49
#      Gabon
#           Libreville: 2023:12:01 13:42:49
#      Ghana
#           Accra: 2023:12:01 12:42:49
#      Guinea
#           Conakry: 2023:12:01 12:42:49
#      Guinea-Bissau
#           Bissau: 2023:12:01 12:42:49
#      Kenya
#           Nairobi: 2023:12:01 15:42:49
#      Lesotho
#           Maseru: 2023:12:01 14:42:49
#      Liberia
#           Monrovia: 2023:12:01 12:42:49
#      Libya
#           Tripoli: 2023:12:01 14:42:49
#      Madagascar
#           Antananarivo: 2023:12:01 15:42:49
#      Malawi
#           Blantyre: 2023:12:01 14:42:49
#      Mali
#           Bamako: 2023:12:01 12:42:49
#      Mauritania
#           Nouakchott: 2023:12:01 12:42:49
#      Mauritius
#           Mauritius: 2023:12:01 16:42:49
#      Morocco
#           Casablanca: 2023:12:01 13:42:49
#      Mozambique
#           Maputo: 2023:12:01 14:42:49
#      Namibia
#           Windhoek: 2023:12:01 14:42:49
#      Niger
#           Niamey: 2023:12:01 13:42:49
#      Nigeria
#           Lagos: 2023:12:01 13:42:49
#      Republic of the Congo
#           Brazzaville: 2023:12:01 13:42:49
#      Rwanda
#           Kigali: 2023:12:01 14:42:49
#      Senegal
#           Dakar: 2023:12:01 12:42:49
#      Seychelles
#           Mahe: 2023:12:01 16:42:49
#      Sierra Leone
#           Freetown: 2023:12:01 12:42:49
#      Somalia
#           Mogadishu: 2023:12:01 15:42:49
#      South Africa
#           Johannesburg: 2023:12:01 14:42:49
#      Sudan
#           Khartoum: 2023:12:01 14:42:49
#      Swaziland
#           Mbabane: 2023:12:01 14:42:49
#      SÃ£o TomÃ© and PrÃ­ncipe
#           Sao_Tome: 2023:12:01 12:42:49
#      Tanzania
#           Dar_es_Salaam: 2023:12:01 15:42:49
#      The Gambia
#           Banjul: 2023:12:01 12:42:49
#      Togo
#           Lome: 2023:12:01 12:42:49
#      Tunisia
#           Tunis: 2023:12:01 13:42:49
#      Uganda
#           Kampala: 2023:12:01 15:42:49
#      Zambia
#           Lusaka: 2023:12:01 14:42:49
#      Zimbabwe
#           Harare: 2023:12:01 14:42:49
# Asia
#      Afghanistan
#           Kabul: 2023:12:01 17:12:49
#      Armenia
#           Yerevan: 2023:12:01 16:42:49
#      Azerbaijan
#           Baku: 2023:12:01 16:42:49
#      Bahrain
#           Bahrain: 2023:12:01 15:42:49
#      Bangladesh
#           Dhaka: 2023:12:01 18:42:49
#      Bhutan
#           Thimphu: 2023:12:01 18:42:49
#      Brunei Darussalam
#           Brunei: 2023:12:01 20:42:49
#      Cambodia
#           Phnom_Penh: 2023:12:01 19:42:49
#      Cyprus
#           Nicosia: 2023:12:01 14:42:49
#      East Timor
#           Dili: 2023:12:01 21:42:49
#      Georgia
#           Tbilisi: 2023:12:01 16:42:49
#      India
#           Calcutta: 2023:12:01 18:12:49
#      Indonesia
#           Jakarta: 2023:12:01 19:42:49
#           Pontianak: 2023:12:01 19:42:49
#           Makassar: 2023:12:01 20:42:49
#           Jayapura: 2023:12:01 21:42:49
#      Iran
#           Tehran: 2023:12:01 16:12:49
#      Iraq
#           Baghdad: 2023:12:01 15:42:49
#      Israel
#           Jerusalem: 2023:12:01 14:42:49
#      Japan
#           Tokyo: 2023:12:01 21:42:49
#      Jordan
#           Amman: 2023:12:01 15:42:49
#      Kazakhstan
#           Almaty: 2023:12:01 18:42:49
#           Qyzylorda: 2023:12:01 17:42:49
#           Aqtobe: 2023:12:01 17:42:49
#           Aqtau: 2023:12:01 17:42:49
#           Oral: 2023:12:01 17:42:49
#      Kuwait
#           Kuwait: 2023:12:01 15:42:49
#      Kyrgyzstan
#           Bishkek: 2023:12:01 18:42:49
#      Laos
#           Vientiane: 2023:12:01 19:42:49
#      Lebanon
#           Beirut: 2023:12:01 14:42:49
#      Malaysia
#           Kuala_Lumpur: 2023:12:01 20:42:49
#           Kuching: 2023:12:01 20:42:49
#      Maldives
#           Maldives: 2023:12:01 17:42:49
#      Mongolia
#           Ulaanbaatar: 2023:12:01 20:42:49
#           Hovd: 2023:12:01 19:42:49
#           Choibalsan: 2023:12:01 20:42:49
#      Myanmar
#           Rangoon: 2023:12:01 19:12:49
#      Nepal
#           Katmandu: 2023:12:01 18:27:49
#      North Korea
#           Pyongyang: 2023:12:01 21:42:49
#      Oman
#           Muscat: 2023:12:01 16:42:49
#      Pakistan
#           Karachi: 2023:12:01 17:42:49
#      People's Republic of China
#           Shanghai: 2023:12:01 20:42:49
#           Harbin: 2023:12:01 20:42:49
#           Chongqing: 2023:12:01 20:42:49
#           Urumqi: 2023:12:01 18:42:49
#           Kashgar: 2023:12:01 18:42:49
#      Philippines
#           Manila: 2023:12:01 20:42:49
#      Qatar
#           Qatar: 2023:12:01 15:42:49
#      Saudi Arabia
#           Riyadh: 2023:12:01 15:42:49
#      Singapore
#           Singapore: 2023:12:01 20:42:49
#      South Korea
#           Seoul: 2023:12:01 21:42:49
#      Sri Lanka
#           Colombo: 2023:12:01 18:12:49
#      Syria
#           Damascus: 2023:12:01 15:42:49
#      Tajikistan
#           Dushanbe: 2023:12:01 17:42:49
#      Thailand
#           Bangkok: 2023:12:01 19:42:49
#      Turkey
#           Istanbul: 2023:12:01 15:42:49
#      Turkmenistan
#           Ashgabat: 2023:12:01 17:42:49
#      United Arab Emirates
#           Dubai: 2023:12:01 16:42:49
#      Uzbekistan
#           Samarkand: 2023:12:01 17:42:49
#           Tashkent: 2023:12:01 17:42:49
#      Vietnam
#           Saigon: 2023:12:01 19:42:49
#      Yemen
#           Aden: 2023:12:01 15:42:49
# Europe
#      Albania
#           Tirane: 2023:12:01 13:42:49
#      Andorra
#           Andorra: 2023:12:01 13:42:49
#      Austria
#           Vienna: 2023:12:01 13:42:49
#      Belarus
#           Minsk: 2023:12:01 15:42:49
#      Belgium
#           Brussels: 2023:12:01 13:42:49
#      Bosnia and Herzegovina
#           Sarajevo: 2023:12:01 13:42:49
#      Bulgaria
#           Sofia: 2023:12:01 14:42:49
#      Croatia
#           Zagreb: 2023:12:01 13:42:49
#      Czech Republic
#           Prague: 2023:12:01 13:42:49
#      Denmark
#           Copenhagen: 2023:12:01 13:42:49
#      Estonia
#           Tallinn: 2023:12:01 14:42:49
#      Finland
#           Helsinki: 2023:12:01 14:42:49
#      France
#           Paris: 2023:12:01 13:42:49
#      Germany
#           Berlin: 2023:12:01 13:42:49
#      Greece
#           Athens: 2023:12:01 14:42:49
#      Hungary
#           Budapest: 2023:12:01 13:42:49
#      Iceland
#           Reykjavik: 2023:12:01 12:42:49
#      Italy
#           Rome: 2023:12:01 13:42:49
#      Kingdom of the Netherlands
#           Amsterdam: 2023:12:01 13:42:49
#      Latvia
#           Riga: 2023:12:01 14:42:49
#      Liechtenstein
#           Vaduz: 2023:12:01 13:42:49
#      Lithuania
#           Vilnius: 2023:12:01 14:42:49
#      Luxembourg
#           Luxembourg: 2023:12:01 13:42:49
#      Macedonia
#           Skopje: 2023:12:01 13:42:49
#      Malta
#           Malta: 2023:12:01 13:42:49
#      Moldova
#           Chisinau: 2023:12:01 14:42:49
#      Monaco
#           Monaco: 2023:12:01 13:42:49
#      Montenegro
#           Podgorica: 2023:12:01 13:42:49
#      Norway
#           Oslo: 2023:12:01 13:42:49
#      Poland
#           Warsaw: 2023:12:01 13:42:49
#      Portugal
#           Lisbon: 2023:12:01 12:42:49
#           Madeira: 2023:12:01 12:42:49
#           Azores: 2023:12:01 11:42:49
#      Republic of Ireland
#           Dublin: 2023:12:01 12:42:49
#      Romania
#           Bucharest: 2023:12:01 14:42:49
#      Russia
#           Kaliningrad: 2023:12:01 14:42:49
#           Moscow: 2023:12:01 15:42:49
#           Volgograd: 2023:12:01 15:42:49
#           Samara: 2023:12:01 16:42:49
#           Yekaterinburg: 2023:12:01 17:42:49
#           Omsk: 2023:12:01 18:42:49
#           Novosibirsk: 2023:12:01 19:42:49
#           Krasnoyarsk: 2023:12:01 19:42:49
#           Irkutsk: 2023:12:01 20:42:49
#           Yakutsk: 2023:12:01 21:42:49
#           Vladivostok: 2023:12:01 22:42:49
#           Sakhalin: 2023:12:01 23:42:49
#           Magadan: 2023:12:01 23:42:49
#           Kamchatka: 2023:12:02 00:42:49
#           Anadyr: 2023:12:02 00:42:49
#      San Marino
#           San_Marino: 2023:12:01 13:42:49
#      Serbia
#           Belgrade: 2023:12:01 13:42:49
#      Slovakia
#           Bratislava: 2023:12:01 13:42:49
#      Slovenia
#           Ljubljana: 2023:12:01 13:42:49
#      Spain
#           Madrid: 2023:12:01 13:42:49
#           Ceuta: 2023:12:01 13:42:49
#           Canary: 2023:12:01 12:42:49
#      Sweden
#           Stockholm: 2023:12:01 13:42:49
#      Switzerland
#           Zurich: 2023:12:01 13:42:49
#      Ukraine
#           Kiev: 2023:12:01 14:42:49
#           Uzhgorod: 2023:12:01 14:42:49
#           Zaporozhye: 2023:12:01 14:42:49
#           Simferopol: 2023:12:01 15:42:49
#      United Kingdom
#           London: 2023:12:01 12:42:49
#      Vatican City
#           Vatican: 2023:12:01 13:42:49
# North America
#      Antigua and Barbuda
#           Antigua: 2023:12:01 08:42:49
#      Bahamas
#           Nassau: 2023:12:01 07:42:49
#      Barbados
#           Barbados: 2023:12:01 08:42:49
#      Belize
#           Belize: 2023:12:01 06:42:49
#      Canada
#           St_Johns: 2023:12:01 09:12:49
#           Halifax: 2023:12:01 08:42:49
#           Glace_Bay: 2023:12:01 08:42:49
#           Moncton: 2023:12:01 08:42:49
#           Goose_Bay: 2023:12:01 08:42:49
#           Blanc-Sablon: 2023:12:01 08:42:49
#           Montreal: 2023:12:01 07:42:49
#           Toronto: 2023:12:01 07:42:49
#           Nipigon: 2023:12:01 07:42:49
#           Thunder_Bay: 2023:12:01 07:42:49
#           Pangnirtung: 2023:12:01 07:42:49
#           Iqaluit: 2023:12:01 07:42:49
#           Atikokan: 2023:12:01 07:42:49
#           Rankin_Inlet: 2023:12:01 06:42:49
#           Winnipeg: 2023:12:01 06:42:49
#           Rainy_River: 2023:12:01 06:42:49
#           Cambridge_Bay: 2023:12:01 05:42:49
#           Regina: 2023:12:01 06:42:49
#           Swift_Current: 2023:12:01 06:42:49
#           Edmonton: 2023:12:01 05:42:49
#           Yellowknife: 2023:12:01 05:42:49
#           Inuvik: 2023:12:01 05:42:49
#           Dawson_Creek: 2023:12:01 05:42:49
#           Vancouver: 2023:12:01 04:42:49
#           Whitehorse: 2023:12:01 05:42:49
#           Dawson: 2023:12:01 05:42:49
#      Costa Rica
#           Costa_Rica: 2023:12:01 06:42:49
#      Cuba
#           Havana: 2023:12:01 07:42:49
#      Dominica
#           Dominica: 2023:12:01 08:42:49
#      Dominican Republic
#           Santo_Domingo: 2023:12:01 08:42:49
#      El Salvador
#           El_Salvador: 2023:12:01 06:42:49
#      Grenada
#           Grenada: 2023:12:01 08:42:49
#      Guatemala
#           Guatemala: 2023:12:01 06:42:49
#      Haiti
#           Guatemala: 2023:12:01 06:42:49
#      Honduras
#           Tegucigalpa: 2023:12:01 06:42:49
#      Jamaica
#           Jamaica: 2023:12:01 07:42:49
#      Mexico
#           Mexico_City: 2023:12:01 06:42:49
#           Cancun: 2023:12:01 07:42:49
#           Merida: 2023:12:01 06:42:49
#           Monterrey: 2023:12:01 06:42:49
#           Mazatlan: 2023:12:01 05:42:49
#           Chihuahua: 2023:12:01 06:42:49
#           Hermosillo: 2023:12:01 05:42:49
#           Tijuana: 2023:12:01 04:42:49
#      Nicaragua
#           Managua: 2023:12:01 06:42:49
#      Panama
#           Panama: 2023:12:01 07:42:49
#      Saint Kitts and Nevis
#           St_Kitts: 2023:12:01 08:42:49
#      Saint Lucia
#           St_Lucia: 2023:12:01 08:42:49
#      Saint Vincent and the Grenadines
#           St_Vincent: 2023:12:01 08:42:49
#      Trinidad and Tobago
#           Port_of_Spain: 2023:12:01 08:42:49
#      United States
#           New_York: 2023:12:01 07:42:49
#           Detroit: 2023:12:01 07:42:49
#           Kentucky: 2023:12:01 07:42:49
#           Kentucky: 2023:12:01 07:42:49
#           Indiana: 2023:12:01 07:42:49
#           Indiana: 2023:12:01 07:42:49
#           Indiana: 2023:12:01 06:42:49
#           Indiana: 2023:12:01 07:42:49
#           Chicago: 2023:12:01 06:42:49
#           Indiana: 2023:12:01 07:42:49
#           Indiana: 2023:12:01 07:42:49
#           Menominee: 2023:12:01 06:42:49
#           North_Dakota: 2023:12:01 06:42:49
#           North_Dakota: 2023:12:01 06:42:49
#           Denver: 2023:12:01 05:42:49
#           Boise: 2023:12:01 05:42:49
#           Shiprock: 2023:12:01 05:42:49
#           Phoenix: 2023:12:01 05:42:49
#           Los_Angeles: 2023:12:01 04:42:49
#           Anchorage: 2023:12:01 03:42:49
#           Juneau: 2023:12:01 03:42:49
#           Yakutat: 2023:12:01 03:42:49
#           Nome: 2023:12:01 03:42:49
#           Adak: 2023:12:01 02:42:49
#           Honolulu: 2023:12:01 02:42:49
# Oceania
#      Australia
#           Lord_Howe: 2023:12:01 23:42:49
#           Hobart: 2023:12:01 23:42:49
#           Currie: 2023:12:01 23:42:49
#           Melbourne: 2023:12:01 23:42:49
#           Sydney: 2023:12:01 23:42:49
#           Broken_Hill: 2023:12:01 23:12:49
#           Brisbane: 2023:12:01 22:42:49
#           Lindeman: 2023:12:01 22:42:49
#           Adelaide: 2023:12:01 23:12:49
#           Darwin: 2023:12:01 22:12:49
#           Perth: 2023:12:01 20:42:49
#      Federated States of Micronesia
#           Truk: 2023:12:01 22:42:49
#           Ponape: 2023:12:01 23:42:49
#           Kosrae: 2023:12:01 23:42:49
#      Fiji
#           Fiji: 2023:12:02 00:42:49
#      Kiribati
#           Tarawa: 2023:12:02 00:42:49
#           Enderbury: 2023:12:02 01:42:49
#           Kiritimati: 2023:12:02 02:42:49
#      Marshall Islands
#           Majuro: 2023:12:02 00:42:49
#           Kwajalein: 2023:12:02 00:42:49
#      Nauru
#           Nauru: 2023:12:02 00:42:49
#      New Zealand
#           Auckland: 2023:12:02 01:42:49
#           Chatham: 2023:12:02 02:27:49
#      Palau
#           Palau: 2023:12:01 21:42:49
#      Papua New Guinea
#           Port_Moresby: 2023:12:01 22:42:49
#      Samoa
#           Apia: 2023:12:02 01:42:49
#      Solomon Islands
#           Guadalcanal: 2023:12:01 23:42:49
#      Tonga
#           Tongatapu: 2023:12:02 01:42:49
#      Tuvalu
#           Funafuti: 2023:12:02 00:42:49
#      Vanuatu
#           Efate: 2023:12:01 23:42:49
# South America
#      Argentina
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#           Argentina: 2023:12:01 09:42:49
#      Bolivia
#           La_Paz: 2023:12:01 08:42:49
#      Brazil
#           Noronha: 2023:12:01 10:42:49
#           Belem: 2023:12:01 09:42:49
#           Fortaleza: 2023:12:01 09:42:49
#           Recife: 2023:12:01 09:42:49
#           Araguaina: 2023:12:01 09:42:49
#           Maceio: 2023:12:01 09:42:49
#           Bahia: 2023:12:01 09:42:49
#           Sao_Paulo: 2023:12:01 09:42:49
#           Campo_Grande: 2023:12:01 08:42:49
#           Cuiaba: 2023:12:01 08:42:49
#           Porto_Velho: 2023:12:01 08:42:49
#           Boa_Vista: 2023:12:01 08:42:49
#           Manaus: 2023:12:01 08:42:49
#           Eirunepe: 2023:12:01 07:42:49
#           Rio_Branco: 2023:12:01 07:42:49
#      Chile
#           Santiago: 2023:12:01 09:42:49
#           Easter: 2023:12:01 07:42:49
#      Colombia
#           Bogota: 2023:12:01 07:42:49
#      Ecuador
#           Guayaquil: 2023:12:01 07:42:49
#           Galapagos: 2023:12:01 06:42:49
#      Guyana
#           Guyana: 2023:12:01 08:42:49
#      Paraguay
#           Asuncion: 2023:12:01 09:42:49
#      Peru
#           Lima: 2023:12:01 07:42:49
#      Suriname
#           Paramaribo: 2023:12:01 09:42:49
#      Uruguay
#           Montevideo: 2023:12:01 09:42:49
#      Venezuela
#           Caracas: 2023:12:01 08:42:49

# %%
import time
keys = sorted(list(dic.keys()))
for key in keys:
    print(f'{key}:00:00')
    for val in dic[key]:
        print(val[0] + " " + val[1])
    time.sleep(2)
# Out:
# 00:00:00
# Russia Kamchatka
# Russia Anadyr
# Fiji Fiji
# Kiribati Tarawa
# Marshall Islands Majuro
# Marshall Islands Kwajalein
# Nauru Nauru
# Tuvalu Funafuti
# 01:00:00
# Kiribati Enderbury
# New Zealand Auckland
# Samoa Apia
# Tonga Tongatapu
# 02:00:00
# United States Adak
# United States Honolulu
# Kiribati Kiritimati
# New Zealand Chatham
# 03:00:00
# United States Anchorage
# United States Juneau
# United States Yakutat
# United States Nome
# 04:00:00
# Canada Vancouver
# Mexico Tijuana
# United States Los_Angeles
# 05:00:00
# Canada Cambridge_Bay
# Canada Edmonton
# Canada Yellowknife
# Canada Inuvik
# Canada Dawson_Creek
# Canada Whitehorse
# Canada Dawson
# Mexico Mazatlan
# Mexico Hermosillo
# United States Denver
# United States Boise
# United States Shiprock
# United States Phoenix
# 06:00:00
# Belize Belize
# Canada Rankin_Inlet
# Canada Winnipeg
# Canada Rainy_River
# Canada Regina
# Canada Swift_Current
# Costa Rica Costa_Rica
# El Salvador El_Salvador
# Guatemala Guatemala
# Haiti Guatemala
# Honduras Tegucigalpa
# Mexico Mexico_City
# Mexico Merida
# Mexico Monterrey
# Mexico Chihuahua
# Nicaragua Managua
# United States Indiana
# United States Chicago
# United States Menominee
# United States North_Dakota
# United States North_Dakota
# Ecuador Galapagos
# 07:00:00
# Bahamas Nassau
# Canada Montreal
# Canada Toronto
# Canada Nipigon
# Canada Thunder_Bay
# Canada Pangnirtung
# Canada Iqaluit
# Canada Atikokan
# Cuba Havana
# Jamaica Jamaica
# Mexico Cancun
# Panama Panama
# United States New_York
# United States Detroit
# United States Kentucky
# United States Kentucky
# United States Indiana
# United States Indiana
# United States Indiana
# United States Indiana
# United States Indiana
# Brazil Eirunepe
# Brazil Rio_Branco
# Chile Easter
# Colombia Bogota
# Ecuador Guayaquil
# Peru Lima
# 08:00:00
# Antigua and Barbuda Antigua
# Barbados Barbados
# Canada Halifax
# Canada Glace_Bay
# Canada Moncton
# Canada Goose_Bay
# Canada Blanc-Sablon
# Dominica Dominica
# Dominican Republic Santo_Domingo
# Grenada Grenada
# Saint Kitts and Nevis St_Kitts
# Saint Lucia St_Lucia
# Saint Vincent and the Grenadines St_Vincent
# Trinidad and Tobago Port_of_Spain
# Bolivia La_Paz
# Brazil Campo_Grande
# Brazil Cuiaba
# Brazil Porto_Velho
# Brazil Boa_Vista
# Brazil Manaus
# Guyana Guyana
# Venezuela Caracas
# 09:00:00
# Canada St_Johns
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Argentina Argentina
# Brazil Belem
# Brazil Fortaleza
# Brazil Recife
# Brazil Araguaina
# Brazil Maceio
# Brazil Bahia
# Brazil Sao_Paulo
# Chile Santiago
# Paraguay Asuncion
# Suriname Paramaribo
# Uruguay Montevideo
# 10:00:00
# Brazil Noronha
# 11:00:00
# Cape Verde Cape_Verde
# Portugal Azores
# 12:00:00
# Burkina Faso Ouagadougou
# CÃ´te d'Ivoire Abidjan
# Ghana Accra
# Guinea Conakry
# Guinea-Bissau Bissau
# Liberia Monrovia
# Mali Bamako
# Mauritania Nouakchott
# Senegal Dakar
# Sierra Leone Freetown
# SÃ£o TomÃ© and PrÃ­ncipe Sao_Tome
# The Gambia Banjul
# Togo Lome
# Iceland Reykjavik
# Portugal Lisbon
# Portugal Madeira
# Republic of Ireland Dublin
# Spain Canary
# United Kingdom London
# 13:00:00
# Algeria Algiers
# Angola Luanda
# Benin Porto-Novo
# Cameroon Douala
# Central African Republic Bangui
# Chad Ndjamena
# Democratic Republic of the Congo Kinshasa
# Equatorial Guinea Malabo
# Gabon Libreville
# Morocco Casablanca
# Niger Niamey
# Nigeria Lagos
# Republic of the Congo Brazzaville
# Tunisia Tunis
# Albania Tirane
# Andorra Andorra
# Austria Vienna
# Belgium Brussels
# Bosnia and Herzegovina Sarajevo
# Croatia Zagreb
# Czech Republic Prague
# Denmark Copenhagen
# France Paris
# Germany Berlin
# Hungary Budapest
# Italy Rome
# Kingdom of the Netherlands Amsterdam
# Liechtenstein Vaduz
# Luxembourg Luxembourg
# Macedonia Skopje
# Malta Malta
# Monaco Monaco
# Montenegro Podgorica
# Norway Oslo
# Poland Warsaw
# San Marino San_Marino
# Serbia Belgrade
# Slovakia Bratislava
# Slovenia Ljubljana
# Spain Madrid
# Spain Ceuta
# Sweden Stockholm
# Switzerland Zurich
# Vatican City Vatican
# 14:00:00
# Botswana Gaborone
# Burundi Bujumbura
# Democratic Republic of the Congo Lubumbashi
# Egypt Cairo
# Lesotho Maseru
# Libya Tripoli
# Malawi Blantyre
# Mozambique Maputo
# Namibia Windhoek
# Rwanda Kigali
# South Africa Johannesburg
# Sudan Khartoum
# Swaziland Mbabane
# Zambia Lusaka
# Zimbabwe Harare
# Cyprus Nicosia
# Israel Jerusalem
# Lebanon Beirut
# Bulgaria Sofia
# Estonia Tallinn
# Finland Helsinki
# Greece Athens
# Latvia Riga
# Lithuania Vilnius
# Moldova Chisinau
# Romania Bucharest
# Russia Kaliningrad
# Ukraine Kiev
# Ukraine Uzhgorod
# Ukraine Zaporozhye
# 15:00:00
# Comoros Comoro
# Djibouti Djibouti
# Eritrea Asmera
# Ethiopia Addis_Ababa
# Kenya Nairobi
# Madagascar Antananarivo
# Somalia Mogadishu
# Tanzania Dar_es_Salaam
# Uganda Kampala
# Bahrain Bahrain
# Iraq Baghdad
# Jordan Amman
# Kuwait Kuwait
# Qatar Qatar
# Saudi Arabia Riyadh
# Syria Damascus
# Turkey Istanbul
# Yemen Aden
# Belarus Minsk
# Russia Moscow
# Russia Volgograd
# Ukraine Simferopol
# 16:00:00
# Mauritius Mauritius
# Seychelles Mahe
# Armenia Yerevan
# Azerbaijan Baku
# Georgia Tbilisi
# Iran Tehran
# Oman Muscat
# United Arab Emirates Dubai
# Russia Samara
# 17:00:00
# Afghanistan Kabul
# Kazakhstan Qyzylorda
# Kazakhstan Aqtobe
# Kazakhstan Aqtau
# Kazakhstan Oral
# Maldives Maldives
# Pakistan Karachi
# Tajikistan Dushanbe
# Turkmenistan Ashgabat
# Uzbekistan Samarkand
# Uzbekistan Tashkent
# Russia Yekaterinburg
# 18:00:00
# Bangladesh Dhaka
# Bhutan Thimphu
# India Calcutta
# Kazakhstan Almaty
# Kyrgyzstan Bishkek
# Nepal Katmandu
# People's Republic of China Urumqi
# People's Republic of China Kashgar
# Sri Lanka Colombo
# Russia Omsk
# 19:00:00
# Cambodia Phnom_Penh
# Indonesia Jakarta
# Indonesia Pontianak
# Laos Vientiane
# Mongolia Hovd
# Myanmar Rangoon
# Thailand Bangkok
# Vietnam Saigon
# Russia Novosibirsk
# Russia Krasnoyarsk
# 20:00:00
# Brunei Darussalam Brunei
# Indonesia Makassar
# Malaysia Kuala_Lumpur
# Malaysia Kuching
# Mongolia Ulaanbaatar
# Mongolia Choibalsan
# People's Republic of China Shanghai
# People's Republic of China Harbin
# People's Republic of China Chongqing
# Philippines Manila
# Singapore Singapore
# Russia Irkutsk
# Australia Perth
# 21:00:00
# East Timor Dili
# Indonesia Jayapura
# Japan Tokyo
# North Korea Pyongyang
# South Korea Seoul
# Russia Yakutsk
# Palau Palau
# 22:00:00
# Russia Vladivostok
# Australia Brisbane
# Australia Lindeman
# Australia Darwin
# Federated States of Micronesia Truk
# Papua New Guinea Port_Moresby
# 23:00:00
# Russia Sakhalin
# Russia Magadan
# Australia Lord_Howe
# Australia Hobart
# Australia Currie
# Australia Melbourne
# Australia Sydney
# Australia Broken_Hill
# Australia Adelaide
# Federated States of Micronesia Ponape
# Federated States of Micronesia Kosrae
# Solomon Islands Guadalcanal
# Vanuatu Efate

# %% [markdown]
# ## Zadanie 5

# %% [markdown]
# Dla klasy `BagOfWords` napisz metody `save` oraz `load` wykorzystujące `json`'a do zapisu i odczytu danych.

# %%
import json
def save(b):
    dic = {a.split(':')[0]: int(a.split(":")[1]) for a in str(b).split(', ')}
    with open('hamlet.json', 'w') as f:
        json.dump(dic, f)
def load(name):
    with open(f'{name}.json', 'r') as f:
        return json.load(f)

# %%
save(b)

# %%
load('hamlet')
# Out:
# {'the': 1349,
#  'and': 1101,
#  'of': 887,
#  'to': 863,
#  'you': 660,
#  'a': 633,
#  'i': 575,
#  'my': 520,
#  'in': 508,
#  'it': 446,
#  'that': 442,
#  'is': 416,
#  'this': 385,
#  'not': 363,
#  'ham': 358,
#  'with': 341,
#  'for': 334,
#  'his': 304,
#  'but': 282,
#  'your': 270,
#  'be': 266,
#  'or': 259,
#  'as': 257,
#  'me': 234,
#  'lord': 226,
#  'he': 225,
#  'what': 221,
#  'so': 212,
#  'king': 203,
#  'him': 197,
#  'have': 195,
#  'by': 193,
#  'are': 187,
#  'will': 183,
#  'do': 172,
#  'no': 158,
#  'we': 157,
#  'all': 147,
#  'if': 144,
#  'on': 144,
#  'our': 128,
#  '': 127,
#  'o': 126,
#  'hamlet': 125,
#  'project': 122,
#  'queen': 121,
#  'from': 117,
#  'shall': 117,
#  'gutenberg': 114,
#  'may': 112,
#  'good': 109,
#  'hor': 109,
#  'at': 108,
#  'come': 108,
#  'let': 106,
#  'thou': 105,
#  'they': 103,
#  'there': 98,
#  'more': 98,
#  'now': 98,
#  'how': 95,
#  'well': 91,
#  'her': 91,
#  'most': 89,
#  'was': 87,
#  'thy': 86,
#  'pol': 86,
#  'like': 82,
#  'would': 81,
#  'us': 79,
#  'such': 78,
#  'them': 75,
#  'know': 75,
#  'sir': 75,
#  'which': 73,
#  'enter': 73,
#  'tis': 73,
#  'any': 72,
#  'must': 72,
#  'th': 72,
#  'go': 71,
#  'father': 70,
#  'give': 69,
#  'very': 67,
#  'then': 66,
#  'did': 66,
#  'love': 66,
#  'hath': 65,
#  'why': 64,
#  'time': 63,
#  'an': 63,
#  'speak': 63,
#  'here': 63,
#  'ill': 62,
#  'laer': 62,
#  'where': 61,
#  'when': 60,
#  'should': 60,
#  'thee': 59,
#  'their': 58,
#  'make': 58,
#  'oph': 58,
#  'work': 57,
#  'upon': 57,
#  'man': 57,
#  'one': 56,
#  'than': 56,
#  'am': 56,
#  'some': 55,
#  'out': 55,
#  'electronic': 54,
#  'say': 54,
#  'other': 53,
#  'works': 51,
#  'these': 51,
#  'can': 50,
#  'much': 50,
#  'too': 50,
#  'she': 50,
#  'who': 49,
#  'think': 48,
#  'see': 48,
#  'horatio': 47,
#  'world': 46,
#  'laertes': 46,
#  'heaven': 46,
#  'play': 46,
#  'thus': 45,
#  'mother': 45,
#  'ros': 45,
#  'had': 44,
#  'up': 43,
#  'tell': 43,
#  'yet': 43,
#  'use': 42,
#  'exit': 40,
#  'copyright': 39,
#  'own': 39,
#  'nor': 38,
#  'both': 37,
#  'take': 37,
#  'night': 37,
#  'look': 37,
#  'death': 37,
#  'exeunt': 37,
#  'ay': 37,
#  'polonius': 36,
#  'clown': 36,
#  'copies': 35,
#  'ghost': 35,
#  'god': 35,
#  'soul': 35,
#  'etext': 34,
#  'cannot': 34,
#  'again': 34,
#  'life': 34,
#  'long': 33,
#  'made': 33,
#  'hear': 33,
#  'could': 33,
#  'mar': 32,
#  'might': 32,
#  'whose': 32,
#  'hold': 31,
#  'nothing': 31,
#  'dead': 31,
#  'mine': 31,
#  'indeed': 31,
#  'distributed': 30,
#  'guildenstern': 30,
#  'ophelia': 30,
#  'heart': 30,
#  'set': 30,
#  'away': 29,
#  'about': 29,
#  'does': 29,
#  'into': 29,
#  'within': 29,
#  'down': 29,
#  'part': 29,
#  'dear': 29,
#  'nature': 29,
#  'guil': 29,
#  'were': 28,
#  'denmark': 28,
#  'doth': 28,
#  'been': 28,
#  'pray': 28,
#  'leave': 28,
#  'terms': 27,
#  'two': 27,
#  'even': 27,
#  'without': 27,
#  'matter': 27,
#  'before': 26,
#  'rosencrantz': 26,
#  'nay': 26,
#  'great': 26,
#  'never': 26,
#  'against': 25,
#  'comes': 25,
#  'head': 25,
#  'sweet': 25,
#  'osr': 25,
#  'those': 24,
#  'scene': 24,
#  'full': 24,
#  'earth': 24,
#  'though': 24,
#  'itself': 24,
#  'put': 24,
#  'shakespeare': 23,
#  'son': 23,
#  'players': 23,
#  'elsinore': 23,
#  'eyes': 23,
#  'show': 23,
#  'means': 23,
#  'service': 22,
#  'day': 22,
#  'form': 22,
#  'seen': 22,
#  'true': 22,
#  'done': 22,
#  'old': 22,
#  'follow': 22,
#  'call': 22,
#  'madness': 22,
#  'foundation': 22,
#  'e': 22,
#  'states': 21,
#  'library': 21,
#  'complete': 21,
#  'only': 21,
#  'first': 21,
#  'end': 21,
#  'many': 21,
#  'off': 21,
#  'fair': 21,
#  'blood': 21,
#  'himself': 21,
#  'keep': 21,
#  'mad': 21,
#  'england': 21,
#  'license': 20,
#  'others': 20,
#  'distribution': 20,
#  'since': 20,
#  'else': 20,
#  'cause': 20,
#  'ber': 20,
#  'friends': 20,
#  'fear': 20,
#  'state': 20,
#  'still': 20,
#  'till': 20,
#  'poor': 20,
#  'words': 20,
#  'william': 19,
#  'provided': 19,
#  'permission': 19,
#  'donations': 19,
#  'act': 19,
#  'thing': 19,
#  'once': 19,
#  'believe': 19,
#  'hand': 19,
#  'aside': 19,
#  'makes': 19,
#  'used': 18,
#  'welcome': 18,
#  'ist': 18,
#  'young': 18,
#  'little': 18,
#  'agreement': 18,
#  'readable': 17,
#  'free': 17,
#  'please': 17,
#  'right': 17,
#  'farewell': 17,
#  'art': 17,
#  'find': 17,
#  'thoughts': 17,
#  'noble': 17,
#  'body': 17,
#  'ear': 17,
#  'sword': 17,
#  'version': 16,
#  'charges': 16,
#  'law': 16,
#  'gentleman': 16,
#  'daughter': 16,
#  'live': 16,
#  'question': 16,
#  'majesty': 16,
#  'hast': 16,
#  'brother': 16,
#  'faith': 16,
#  'youth': 16,
#  'marry': 16,
#  'speech': 16,
#  'fortune': 16,
#  'ebook': 15,
#  'united': 15,
#  'copy': 15,
#  'inc': 15,
#  'has': 15,
#  'machine': 15,
#  'last': 15,
#  'university': 15,
#  'including': 15,
#  'word': 15,
#  'purpose': 15,
#  'fortinbras': 15,
#  'gertrude': 15,
#  'castle': 15,
#  'stand': 15,
#  'yourself': 15,
#  'watch': 15,
#  'therefore': 15,
#  'mark': 15,
#  'eye': 15,
#  'bear': 15,
#  'better': 15,
#  'tongue': 15,
#  'drink': 15,
#  'while': 15,
#  'men': 15,
#  'said': 15,
#  'between': 15,
#  'after': 15,
#  'help': 15,
#  'lady': 15,
#  'personal': 14,
#  'commercial': 14,
#  'includes': 14,
#  'further': 14,
#  'trademark': 14,
#  'each': 14,
#  'ever': 14,
#  'carnegie': 14,
#  'mellon': 14,
#  'second': 14,
#  'kind': 14,
#  'friend': 14,
#  'answer': 14,
#  'ho': 14,
#  'charge': 14,
#  'gone': 14,
#  'something': 14,
#  'goes': 14,
#  'mind': 14,
#  'heard': 14,
#  'spirit': 14,
#  'oer': 14,
#  'grief': 14,
#  'reason': 14,
#  'thine': 14,
#  'forth': 14,
#  'gentlemen': 14,
#  'phrase': 14,
#  'another': 14,
#  'murther': 14,
#  'sent': 14,
#  'rest': 14,
#  'dost': 14,
#  'sings': 14,
#  'under': 13,
#  'commercially': 13,
#  'prohibited': 13,
#  'download': 13,
#  'membership': 13,
#  'information': 13,
#  'refund': 13,
#  'norway': 13,
#  'same': 13,
#  'air': 13,
#  'duty': 13,
#  'room': 13,
#  'ourselves': 13,
#  'things': 13,
#  'sense': 13,
#  'grace': 13,
#  'name': 13,
#  'none': 13,
#  'virtue': 13,
#  'way': 13,
#  'rey': 13,
#  'literary': 13,
#  'archive': 13,
#  'almost': 12,
#  'access': 12,
#  'thousand': 12,
#  'fee': 12,
#  'receive': 12,
#  'marcellus': 12,
#  'haste': 12,
#  'myself': 12,
#  'together': 12,
#  'stay': 12,
#  'int': 12,
#  'ere': 12,
#  'fire': 12,
#  'voice': 12,
#  'oft': 12,
#  'being': 12,
#  'twere': 12,
#  'business': 12,
#  'madam': 12,
#  'remember': 12,
#  'saw': 12,
#  'hands': 12,
#  'sleep': 12,
#  'bring': 12,
#  'fit': 12,
#  'revenge': 12,
#  'grave': 12,
#  'passion': 12,
#  'laws': 11,
#  'neither': 11,
#  'get': 11,
#  'days': 11,
#  'person': 11,
#  'particular': 11,
#  'courtier': 11,
#  'bed': 11,
#  'honest': 11,
#  'tonight': 11,
#  'thought': 11,
#  'een': 11,
#  'through': 11,
#  'takes': 11,
#  'far': 11,
#  'best': 11,
#  'alone': 11,
#  'seem': 11,
#  'face': 11,
#  'fellow': 11,
#  'hell': 11,
#  'honour': 11,
#  'foul': 11,
#  'deed': 11,
#  'near': 11,
#  'wind': 11,
#  'given': 11,
#  'mean': 11,
#  'villain': 11,
#  'paragraph': 11,
#  'f': 11,
#  'read': 10,
#  'sure': 10,
#  'hour': 10,
#  'letters': 10,
#  'small': 10,
#  'provide': 10,
#  'agree': 10,
#  'thanks': 10,
#  'meet': 10,
#  'place': 10,
#  'awhile': 10,
#  'peace': 10,
#  'soft': 10,
#  'arms': 10,
#  'memory': 10,
#  'late': 10,
#  'uncle': 10,
#  'doubt': 10,
#  'news': 10,
#  'excellent': 10,
#  'command': 10,
#  'general': 10,
#  'action': 10,
#  'alas': 10,
#  'aught': 10,
#  'offence': 10,
#  'swear': 10,
#  'fine': 10,
#  'pyrrhus': 10,
#  'fall': 10,
#  'husband': 10,
#  'lie': 10,
#  'noise': 10,
#  'skull': 10,
#  'distribute': 9,
#  'limited': 9,
#  'b': 9,
#  'damages': 9,
#  'money': 9,
#  'paid': 9,
#  'return': 9,
#  'freely': 9,
#  'bernardo': 9,
#  'attendants': 9,
#  'ground': 9,
#  'sight': 9,
#  'ears': 9,
#  'strange': 9,
#  'fell': 9,
#  'lost': 9,
#  'walk': 9,
#  'dot': 9,
#  'gives': 9,
#  'came': 9,
#  'seek': 9,
#  'breath': 9,
#  'judgment': 9,
#  'light': 9,
#  'custom': 9,
#  'draw': 9,
#  'lay': 9,
#  'age': 9,
#  'hope': 9,
#  'three': 9,
#  'thank': 9,
#  'behind': 9,
#  'country': 8,
#  'public': 8,
#  'below': 8,
#  'tax': 8,
#  'visit': 8,
#  'print': 8,
#  'effect': 8,
#  'replacement': 8,
#  'either': 8,
#  'defect': 8,
#  'note': 8,
#  'received': 8,
#  'choose': 8,
#  'fran': 8,
#  'says': 8,
#  'sit': 8,
#  'break': 8,
#  'looks': 8,
#  'pale': 8,
#  'ont': 8,
#  'known': 8,
#  'unto': 8,
#  'sun': 8,
#  'wherein': 8,
#  'power': 8,
#  'flourish': 8,
#  'sister': 8,
#  'woe': 8,
#  'joy': 8,
#  'wife': 8,
#  'less': 8,
#  'black': 8,
#  'truly': 8,
#  'shows': 8,
#  'back': 8,
#  'woman': 8,
#  'tears': 8,
#  'lordship': 8,
#  'fashion': 8,
#  'grow': 8,
#  'shame': 8,
#  'every': 8,
#  'understand': 8,
#  'tot': 8,
#  'wilt': 8,
#  'adieu': 8,
#  'hither': 8,
#  'times': 8,
#  'music': 8,
#  'falls': 8,
#  'gave': 8,
#  'except': 8,
#  'comply': 8,
#  'quick': 8,
#  'devil': 8,
#  'conscience': 8,
#  'cost': 7,
#  'located': 7,
#  'start': 7,
#  'future': 7,
#  'etexts': 7,
#  'certain': 7,
#  'need': 7,
#  'prince': 7,
#  'month': 7,
#  'year': 7,
#  'try': 7,
#  'medium': 7,
#  'osric': 7,
#  'piece': 7,
#  't': 7,
#  'list': 7,
#  'coming': 7,
#  'sound': 7,
#  'wholesome': 7,
#  'loves': 7,
#  'whole': 7,
#  'lose': 7,
#  'beg': 7,
#  'beseech': 7,
#  'dust': 7,
#  'common': 7,
#  'die': 7,
#  'bound': 7,
#  'desire': 7,
#  'obey': 7,
#  'rank': 7,
#  'top': 7,
#  'house': 7,
#  'wisdom': 7,
#  'maid': 7,
#  'enough': 7,
#  'fool': 7,
#  'table': 7,
#  'needs': 7,
#  'already': 7,
#  'whom': 7,
#  'heavens': 7,
#  'found': 7,
#  'anything': 7,
#  'bloody': 7,
#  'turn': 7,
#  'dies': 7,
#  'capt': 7,
#  'drownd': 7,
#  'distributing': 7,
#  'ebooks': 7,
#  'associated': 7,
#  'section': 7,
#  'anyone': 6,
#  'using': 6,
#  'often': 6,
#  'domain': 6,
#  'plain': 6,
#  'volunteers': 6,
#  'next': 6,
#  'million': 6,
#  'audience': 6,
#  'legal': 6,
#  'protected': 6,
#  'fees': 6,
#  'warranties': 6,
#  'c': 6,
#  'send': 6,
#  'voltemand': 6,
#  'reynaldo': 6,
#  'ambassadors': 6,
#  'lords': 6,
#  'soldiers': 6,
#  'struck': 6,
#  'cold': 6,
#  'bid': 6,
#  'dane': 6,
#  'star': 6,
#  'course': 6,
#  'buried': 6,
#  'march': 6,
#  'cast': 6,
#  'toward': 6,
#  'seald': 6,
#  'stood': 6,
#  'hot': 6,
#  'cock': 6,
#  'wrong': 6,
#  'guilty': 6,
#  'whether': 6,
#  'sea': 6,
#  'truth': 6,
#  'season': 6,
#  'dare': 6,
#  'gracious': 6,
#  'dumb': 6,
#  'ii': 6,
#  'sorrow': 6,
#  'marriage': 6,
#  'dream': 6,
#  'wouldst': 6,
#  'mouth': 6,
#  'pardon': 6,
#  'health': 6,
#  'beast': 6,
#  'discourse': 6,
#  'longer': 6,
#  'wicked': 6,
#  'prithee': 6,
#  'point': 6,
#  'beard': 6,
#  'fare': 6,
#  'withal': 6,
#  'choice': 6,
#  'shot': 6,
#  'beauty': 6,
#  'lies': 6,
#  'double': 6,
#  'dull': 6,
#  'false': 6,
#  'circumstance': 6,
#  'vows': 6,
#  'shape': 6,
#  'brain': 6,
#  'prison': 6,
#  'fat': 6,
#  'crown': 6,
#  'wit': 6,
#  'court': 6,
#  'damned': 6,
#  'lack': 6,
#  'touch': 6,
#  'property': 6,
#  'move': 6,
#  'brought': 6,
#  'pass': 6,
#  'home': 6,
#  'round': 6,
#  'herself': 6,
#  'arras': 6,
#  'bad': 6,
#  'ambition': 6,
#  'laugh': 6,
#  'fort': 6,
#  'unless': 6,
#  'yours': 6,
#  'heavy': 6,
#  'speaks': 6,
#  'begin': 6,
#  'anon': 6,
#  'new': 6,
#  'proof': 6,
#  'ha': 6,
#  'feed': 6,
#  'danish': 6,
#  'killd': 6,
#  'poison': 6,
#  'slain': 6,
#  'laid': 6,
#  'hit': 6,
#  'collection': 6,
#  'wager': 6,
#  'foils': 6,
#  'water': 6,
#  'parts': 5,
#  'wwwgutenbergorg': 5,
#  'check': 5,
#  'author': 5,
#  'date': 5,
#  'file': 5,
#  'entertainment': 5,
#  'tragedy': 5,
#  'posted': 5,
#  'wish': 5,
#  'written': 5,
#  'four': 5,
#  'ten': 5,
#  'number': 5,
#  'subject': 5,
#  'additional': 5,
#  'expense': 5,
#  'warranty': 5,
#  'defective': 5,
#  'liability': 5,
#  'express': 5,
#  'above': 5,
#  'following': 5,
#  'addition': 5,
#  'nephew': 5,
#  'cornelius': 5,
#  'twelve': 5,
#  'quiet': 5,
#  'figure': 5,
#  'warlike': 5,
#  'thyself': 5,
#  'land': 5,
#  'main': 5,
#  'motive': 5,
#  'prologue': 5,
#  'spirits': 5,
#  'trumpet': 5,
#  'stir': 5,
#  'impart': 5,
#  'morning': 5,
#  'attendant': 5,
#  'kingdom': 5,
#  'funeral': 5,
#  'writ': 5,
#  'told': 5,
#  'dread': 5,
#  'france': 5,
#  'confess': 5,
#  'hard': 5,
#  'colour': 5,
#  'seems': 5,
#  'visage': 5,
#  'fie': 5,
#  'fault': 5,
#  'throw': 5,
#  'gentle': 5,
#  'sits': 5,
#  'flesh': 5,
#  'grows': 5,
#  'change': 5,
#  'disposition': 5,
#  'report': 5,
#  'methinks': 5,
#  'knew': 5,
#  'honourd': 5,
#  'yes': 5,
#  'perchance': 5,
#  'silence': 5,
#  'perhaps': 5,
#  'safety': 5,
#  'danger': 5,
#  'moon': 5,
#  'blessing': 5,
#  'humbly': 5,
#  'pay': 5,
#  'damnd': 5,
#  'souls': 5,
#  'base': 5,
#  'puts': 5,
#  'cries': 5,
#  'direct': 5,
#  'hearing': 5,
#  'shalt': 5,
#  'fast': 5,
#  'gifts': 5,
#  'went': 5,
#  'natural': 5,
#  'brief': 5,
#  'holds': 5,
#  'sudden': 5,
#  'vile': 5,
#  'knave': 5,
#  'stage': 5,
#  'fingers': 5,
#  'liberty': 5,
#  'mass': 5,
#  'closet': 5,
#  'hat': 5,
#  'arm': 5,
#  'over': 5,
#  'hide': 5,
#  'whereon': 5,
#  'commission': 5,
#  'rather': 5,
#  'short': 5,
#  'presently': 5,
#  'honesty': 5,
#  'save': 5,
#  'bodies': 5,
#  'cry': 5,
#  'sing': 5,
#  'themselves': 5,
#  'player': 5,
#  'brains': 5,
#  'french': 5,
#  'fly': 5,
#  'lovd': 5,
#  'priam': 5,
#  'treason': 5,
#  'mortal': 5,
#  'slave': 5,
#  'conceit': 5,
#  'drown': 5,
#  'dangerous': 5,
#  'nunnery': 5,
#  'christian': 5,
#  'eat': 5,
#  'patience': 5,
#  'half': 5,
#  'forgot': 5,
#  'door': 5,
#  'prepare': 5,
#  'owner': 5,
#  'alexander': 5,
#  'woot': 5,
#  'carriages': 5,
#  'compliance': 5,
#  'included': 4,
#  'online': 4,
#  'files': 4,
#  'proud': 4,
#  'reading': 4,
#  'official': 4,
#  'hundred': 4,
#  'computer': 4,
#  'contain': 4,
#  'links': 4,
#  'ascii': 4,
#  'disclaimer': 4,
#  'equipment': 4,
#  'strict': 4,
#  'breach': 4,
#  'notice': 4,
#  'sending': 4,
#  'electronically': 4,
#  'otherwise': 4,
#  'implied': 4,
#  'limitation': 4,
#  'its': 4,
#  'directly': 4,
#  'royalty': 4,
#  'v': 4,
#  'present': 4,
#  'priest': 4,
#  'soldier': 4,
#  'ladies': 4,
#  'platform': 4,
#  'sick': 4,
#  'guard': 4,
#  'twice': 4,
#  'twill': 4,
#  'appear': 4,
#  'gross': 4,
#  'knows': 4,
#  'cannon': 4,
#  'image': 4,
#  'lands': 4,
#  'returnd': 4,
#  'strong': 4,
#  'stars': 4,
#  'stands': 4,
#  'ease': 4,
#  'treasure': 4,
#  'stop': 4,
#  'violence': 4,
#  'throat': 4,
#  'herein': 4,
#  'gainst': 4,
#  'birth': 4,
#  'consent': 4,
#  'discretion': 4,
#  'remembrance': 4,
#  'affair': 4,
#  'follows': 4,
#  'thinking': 4,
#  'frame': 4,
#  'commend': 4,
#  'native': 4,
#  'favour': 4,
#  'cousin': 4,
#  'clouds': 4,
#  'hang': 4,
#  'lives': 4,
#  'died': 4,
#  'immediate': 4,
#  'wittenberg': 4,
#  'ah': 4,
#  'months': 4,
#  'grown': 4,
#  'salt': 4,
#  'speed': 4,
#  'incestuous': 4,
#  'glad': 4,
#  'forget': 4,
#  'teach': 4,
#  'deep': 4,
#  'mock': 4,
#  'thrift': 4,
#  'thrice': 4,
#  'length': 4,
#  'kept': 4,
#  'methought': 4,
#  'motion': 4,
#  'lookd': 4,
#  'countenance': 4,
#  'assume': 4,
#  'iii': 4,
#  'wide': 4,
#  'affection': 4,
#  'occasion': 4,
#  'few': 4,
#  'censure': 4,
#  'habit': 4,
#  'tend': 4,
#  'tender': 4,
#  'heat': 4,
#  'leisure': 4,
#  'ways': 4,
#  'iv': 4,
#  'keeps': 4,
#  'infinite': 4,
#  'bones': 4,
#  'horrible': 4,
#  'beneath': 4,
#  'desperate': 4,
#  'imagination': 4,
#  'lead': 4,
#  'pity': 4,
#  'lend': 4,
#  'tale': 4,
#  'didst': 4,
#  'unnatural': 4,
#  'sleeping': 4,
#  'angel': 4,
#  'cursed': 4,
#  'instant': 4,
#  'bosom': 4,
#  'distracted': 4,
#  'yea': 4,
#  'commandment': 4,
#  'book': 4,
#  'secret': 4,
#  'desires': 4,
#  'wild': 4,
#  'sorry': 4,
#  ...}
